# %%
"""DenseNet models for Keras.
# Reference paper
- [Densely Connected Convolutional Networks]
  (https://arxiv.org/abs/1608.06993) (CVPR 2017 Best Paper Award)
# Reference implementation
- [Torch DenseNets]
  (https://github.com/liuzhuang13/DenseNet/blob/master/models/densenet.lua)
- [TensorNets]
  (https://github.com/taehoonlee/tensornets/blob/master/tensornets/densenets.py)
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

### setting the different directories 

# on the server (linux):
# where to find the images:
home_dir = '/home/rick/Documents/HannahZ'
# folder where to save code and so on
code_dir = home_dir + '/Code'
# where to save the final models
model_dir = code_dir + '/Final_models'
# where to save the logs for visualization in TensorBoard
log_dir = code_dir + '/logs'
# where to save the weights
new_weight_dir = code_dir + '/new_weights'

modelname = 'DenseNet121'

# on my computer (windows):
# where to find the images:
#home_dir = '\\Users\\ThinkPad User\\Google Drive\\DeepSolaris'
# folder where to save code and so on
#code_dir = '\\Users\\ThinkPad User\\Google Drive\\Master_thesis_H_Z_DL&NN\\Coding'
# where to save the final models
#model_dir = code_dir + '\\Final_models_saved'
# where to save the logs for visualization in TensorBoard
#log_dir = code_dir + '\\logs'
import os
os.chdir(home_dir)

# %%
from keras import backend as K
from keras.models import Model
from keras.layers import Activation
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import ZeroPadding2D
from keras.utils.data_utils import get_file
from keras.engine import get_source_inputs
from keras.applications import imagenet_utils
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import _obtain_input_shape 

from sklearn.model_selection import cross_validate
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.losses import binary_crossentropy


from random import randrange
from random import seed
from random import sample
import tensorflow as tf


import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from time import time
from datetime import timedelta
import math
from sklearn.model_selection import train_test_split
from datetime import datetime
from keras.preprocessing import image
from keras.optimizers import SGD
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import keras
from keras.callbacks import Callback

os.chdir(code_dir)
import DenseNet_pretrained
from DenseNet_pretrained import DenseNet
from DenseNet_pretrained import conv_block
from DenseNet_pretrained import transition_block
from DenseNet_pretrained import dense_block
from DenseNet_pretrained import DenseNet121
from Learning_rate_scheduler import LrReducer
from CyclicLR import CyclicLR
# Out:
# Using TensorFlow backend.

# %%
seed(0)
### Helper metrics functions

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
    
def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
    
    
def fbeta_score(y_true, y_pred, beta=1):
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score
def fmeasure(y_true, y_pred):
    return fbeta_score(y_true, y_pred, beta=1)

no_of_epochs = 0

### check if data are in the right format
K.image_data_format() == 'channels_last'

os.chdir(home_dir)
train_images = np.load('training_images_AcMüDüHo.npy')
valid_images = np.load('validation_images_AcMüDüHo.npy')
test_images = np.load('test_images_AcMüDüHo.npy')
train_labels = np.load('training_labels_AcMüDüHo.npy')
valid_labels = np.load('validation_labels_AcMüDüHo.npy')
test_labels = np.load('test_labels_AcMüDüHo.npy')

print("Size of:")
print("- Training-set:\t\t{}".format(len(train_labels)))
print("- Validation-set:\t{}".format(len(valid_labels)))
print("- Test-set:\t\t{}".format(len(test_labels)))
# Out:
# Size of:
# - Training-set:		3357
# - Validation-set:	374
# - Test-set:		934

# %%
# choose training specifications (None or 'imagenet')
weights = 'imagenet'
#tf.reset_default_graph()

# importing the currently used model
os.chdir(code_dir)

### create the base pre-trained model
Model_base = DenseNet_pretrained.DenseNet121(weights = weights, include_top=False)
# find out how many layers exist to find right number of trainable layers
len(Model_base.layers)
# Out:
# 426

# %%
# choose layers for split
for i, layer in enumerate(Model_base.layers):
#     if ('pool' in layer.name):
        print(i, layer.name)
# Out:
# 0 input_1
# 1 zero_padding2d_1
# 2 conv1/conv
# 3 conv1/bn
# 4 conv1/relu
# 5 zero_padding2d_2
# 6 pool1
# 7 conv2_block1_0_bn
# 8 conv2_block1_0_relu
# 9 conv2_block1_1_conv
# 10 conv2_block1_1_bn
# 11 conv2_block1_1_relu
# 12 conv2_block1_2_conv
# 13 conv2_block1_concat
# 14 conv2_block2_0_bn
# 15 conv2_block2_0_relu
# 16 conv2_block2_1_conv
# 17 conv2_block2_1_bn
# 18 conv2_block2_1_relu
# 19 conv2_block2_2_conv
# 20 conv2_block2_concat
# 21 conv2_block3_0_bn
# 22 conv2_block3_0_relu
# 23 conv2_block3_1_conv
# 24 conv2_block3_1_bn
# 25 conv2_block3_1_relu
# 26 conv2_block3_2_conv
# 27 conv2_block3_concat
# 28 conv2_block4_0_bn
# 29 conv2_block4_0_relu
# 30 conv2_block4_1_conv
# 31 conv2_block4_1_bn
# 32 conv2_block4_1_relu
# 33 conv2_block4_2_conv
# 34 conv2_block4_concat
# 35 conv2_block5_0_bn
# 36 conv2_block5_0_relu
# 37 conv2_block5_1_conv
# 38 conv2_block5_1_bn
# 39 conv2_block5_1_relu
# 40 conv2_block5_2_conv
# 41 conv2_block5_concat
# 42 conv2_block6_0_bn
# 43 conv2_block6_0_relu
# 44 conv2_block6_1_conv
# 45 conv2_block6_1_bn
# 46 conv2_block6_1_relu
# 47 conv2_block6_2_conv
# 48 conv2_block6_concat
# 49 pool2_bn
# 50 pool2_relu
# 51 pool2_conv
# 52 pool2_pool
# 53 conv3_block1_0_bn
# 54 conv3_block1_0_relu
# 55 conv3_block1_1_conv
# 56 conv3_block1_1_bn
# 57 conv3_block1_1_relu
# 58 conv3_block1_2_conv
# 59 conv3_block1_concat
# 60 conv3_block2_0_bn
# 61 conv3_block2_0_relu
# 62 conv3_block2_1_conv
# 63 conv3_block2_1_bn
# 64 conv3_block2_1_relu
# 65 conv3_block2_2_conv
# 66 conv3_block2_concat
# 67 conv3_block3_0_bn
# 68 conv3_block3_0_relu
# 69 conv3_block3_1_conv
# 70 conv3_block3_1_bn
# 71 conv3_block3_1_relu
# 72 conv3_block3_2_conv
# 73 conv3_block3_concat
# 74 conv3_block4_0_bn
# 75 conv3_block4_0_relu
# 76 conv3_block4_1_conv
# 77 conv3_block4_1_bn
# 78 conv3_block4_1_relu
# 79 conv3_block4_2_conv
# 80 conv3_block4_concat
# 81 conv3_block5_0_bn
# 82 conv3_block5_0_relu
# 83 conv3_block5_1_conv
# 84 conv3_block5_1_bn
# 85 conv3_block5_1_relu
# 86 conv3_block5_2_conv
# 87 conv3_block5_concat
# 88 conv3_block6_0_bn
# 89 conv3_block6_0_relu
# 90 conv3_block6_1_conv
# 91 conv3_block6_1_bn
# 92 conv3_block6_1_relu
# 93 conv3_block6_2_conv
# 94 conv3_block6_concat
# 95 conv3_block7_0_bn
# 96 conv3_block7_0_relu
# 97 conv3_block7_1_conv
# 98 conv3_block7_1_bn
# 99 conv3_block7_1_relu
# 100 conv3_block7_2_conv
# 101 conv3_block7_concat
# 102 conv3_block8_0_bn
# 103 conv3_block8_0_relu
# 104 conv3_block8_1_conv
# 105 conv3_block8_1_bn
# 106 conv3_block8_1_relu
# 107 conv3_block8_2_conv
# 108 conv3_block8_concat
# 109 conv3_block9_0_bn
# 110 conv3_block9_0_relu
# 111 conv3_block9_1_conv
# 112 conv3_block9_1_bn
# 113 conv3_block9_1_relu
# 114 conv3_block9_2_conv
# 115 conv3_block9_concat
# 116 conv3_block10_0_bn
# 117 conv3_block10_0_relu
# 118 conv3_block10_1_conv
# 119 conv3_block10_1_bn
# 120 conv3_block10_1_relu
# 121 conv3_block10_2_conv
# 122 conv3_block10_concat
# 123 conv3_block11_0_bn
# 124 conv3_block11_0_relu
# 125 conv3_block11_1_conv
# 126 conv3_block11_1_bn
# 127 conv3_block11_1_relu
# 128 conv3_block11_2_conv
# 129 conv3_block11_concat
# 130 conv3_block12_0_bn
# 131 conv3_block12_0_relu
# 132 conv3_block12_1_conv
# 133 conv3_block12_1_bn
# 134 conv3_block12_1_relu
# 135 conv3_block12_2_conv
# 136 conv3_block12_concat
# 137 pool3_bn
# 138 pool3_relu
# 139 pool3_conv
# 140 pool3_pool
# 141 conv4_block1_0_bn
# 142 conv4_block1_0_relu
# 143 conv4_block1_1_conv
# 144 conv4_block1_1_bn
# 145 conv4_block1_1_relu
# 146 conv4_block1_2_conv
# 147 conv4_block1_concat
# 148 conv4_block2_0_bn
# 149 conv4_block2_0_relu
# 150 conv4_block2_1_conv
# 151 conv4_block2_1_bn
# 152 conv4_block2_1_relu
# 153 conv4_block2_2_conv
# 154 conv4_block2_concat
# 155 conv4_block3_0_bn
# 156 conv4_block3_0_relu
# 157 conv4_block3_1_conv
# 158 conv4_block3_1_bn
# 159 conv4_block3_1_relu
# 160 conv4_block3_2_conv
# 161 conv4_block3_concat
# 162 conv4_block4_0_bn
# 163 conv4_block4_0_relu
# 164 conv4_block4_1_conv
# 165 conv4_block4_1_bn
# 166 conv4_block4_1_relu
# 167 conv4_block4_2_conv
# 168 conv4_block4_concat
# 169 conv4_block5_0_bn
# 170 conv4_block5_0_relu
# 171 conv4_block5_1_conv
# 172 conv4_block5_1_bn
# 173 conv4_block5_1_relu
# 174 conv4_block5_2_conv
# 175 conv4_block5_concat
# 176 conv4_block6_0_bn
# 177 conv4_block6_0_relu
# 178 conv4_block6_1_conv
# 179 conv4_block6_1_bn
# 180 conv4_block6_1_relu
# 181 conv4_block6_2_conv
# 182 conv4_block6_concat
# 183 conv4_block7_0_bn
# 184 conv4_block7_0_relu
# 185 conv4_block7_1_conv
# 186 conv4_block7_1_bn
# 187 conv4_block7_1_relu
# 188 conv4_block7_2_conv
# 189 conv4_block7_concat
# 190 conv4_block8_0_bn
# 191 conv4_block8_0_relu
# 192 conv4_block8_1_conv
# 193 conv4_block8_1_bn
# 194 conv4_block8_1_relu
# 195 conv4_block8_2_conv
# 196 conv4_block8_concat
# 197 conv4_block9_0_bn
# 198 conv4_block9_0_relu
# 199 conv4_block9_1_conv
# 200 conv4_block9_1_bn
# 201 conv4_block9_1_relu
# 202 conv4_block9_2_conv
# 203 conv4_block9_concat
# 204 conv4_block10_0_bn
# 205 conv4_block10_0_relu
# 206 conv4_block10_1_conv
# 207 conv4_block10_1_bn
# 208 conv4_block10_1_relu
# 209 conv4_block10_2_conv
# 210 conv4_block10_concat
# 211 conv4_block11_0_bn
# 212 conv4_block11_0_relu
# 213 conv4_block11_1_conv
# 214 conv4_block11_1_bn
# 215 conv4_block11_1_relu
# 216 conv4_block11_2_conv
# 217 conv4_block11_concat
# 218 conv4_block12_0_bn
# 219 conv4_block12_0_relu
# 220 conv4_block12_1_conv
# 221 conv4_block12_1_bn
# 222 conv4_block12_1_relu
# 223 conv4_block12_2_conv
# 224 conv4_block12_concat
# 225 conv4_block13_0_bn
# 226 conv4_block13_0_relu
# 227 conv4_block13_1_conv
# 228 conv4_block13_1_bn
# 229 conv4_block13_1_relu
# 230 conv4_block13_2_conv
# 231 conv4_block13_concat
# 232 conv4_block14_0_bn
# 233 conv4_block14_0_relu
# 234 conv4_block14_1_conv
# 235 conv4_block14_1_bn
# 236 conv4_block14_1_relu
# 237 conv4_block14_2_conv
# 238 conv4_block14_concat
# 239 conv4_block15_0_bn
# 240 conv4_block15_0_relu
# 241 conv4_block15_1_conv
# 242 conv4_block15_1_bn
# 243 conv4_block15_1_relu
# 244 conv4_block15_2_conv
# 245 conv4_block15_concat
# 246 conv4_block16_0_bn
# 247 conv4_block16_0_relu
# 248 conv4_block16_1_conv
# 249 conv4_block16_1_bn
# 250 conv4_block16_1_relu
# 251 conv4_block16_2_conv
# 252 conv4_block16_concat
# 253 conv4_block17_0_bn
# 254 conv4_block17_0_relu
# 255 conv4_block17_1_conv
# 256 conv4_block17_1_bn
# 257 conv4_block17_1_relu
# 258 conv4_block17_2_conv
# 259 conv4_block17_concat
# 260 conv4_block18_0_bn
# 261 conv4_block18_0_relu
# 262 conv4_block18_1_conv
# 263 conv4_block18_1_bn
# 264 conv4_block18_1_relu
# 265 conv4_block18_2_conv
# 266 conv4_block18_concat
# 267 conv4_block19_0_bn
# 268 conv4_block19_0_relu
# 269 conv4_block19_1_conv
# 270 conv4_block19_1_bn
# 271 conv4_block19_1_relu
# 272 conv4_block19_2_conv
# 273 conv4_block19_concat
# 274 conv4_block20_0_bn
# 275 conv4_block20_0_relu
# 276 conv4_block20_1_conv
# 277 conv4_block20_1_bn
# 278 conv4_block20_1_relu
# 279 conv4_block20_2_conv
# 280 conv4_block20_concat
# 281 conv4_block21_0_bn
# 282 conv4_block21_0_relu
# 283 conv4_block21_1_conv
# 284 conv4_block21_1_bn
# 285 conv4_block21_1_relu
# 286 conv4_block21_2_conv
# 287 conv4_block21_concat
# 288 conv4_block22_0_bn
# 289 conv4_block22_0_relu
# 290 conv4_block22_1_conv
# 291 conv4_block22_1_bn
# 292 conv4_block22_1_relu
# 293 conv4_block22_2_conv
# 294 conv4_block22_concat
# 295 conv4_block23_0_bn
# 296 conv4_block23_0_relu
# 297 conv4_block23_1_conv
# 298 conv4_block23_1_bn
# 299 conv4_block23_1_relu
# 300 conv4_block23_2_conv
# 301 conv4_block23_concat
# 302 conv4_block24_0_bn
# 303 conv4_block24_0_relu
# 304 conv4_block24_1_conv
# 305 conv4_block24_1_bn
# 306 conv4_block24_1_relu
# 307 conv4_block24_2_conv
# 308 conv4_block24_concat
# 309 pool4_bn
# 310 pool4_relu
# 311 pool4_conv
# 312 pool4_pool
# 313 conv5_block1_0_bn
# 314 conv5_block1_0_relu
# 315 conv5_block1_1_conv
# 316 conv5_block1_1_bn
# 317 conv5_block1_1_relu
# 318 conv5_block1_2_conv
# 319 conv5_block1_concat
# 320 conv5_block2_0_bn
# 321 conv5_block2_0_relu
# 322 conv5_block2_1_conv
# 323 conv5_block2_1_bn
# 324 conv5_block2_1_relu
# 325 conv5_block2_2_conv
# 326 conv5_block2_concat
# 327 conv5_block3_0_bn
# 328 conv5_block3_0_relu
# 329 conv5_block3_1_conv
# 330 conv5_block3_1_bn
# 331 conv5_block3_1_relu
# 332 conv5_block3_2_conv
# 333 conv5_block3_concat
# 334 conv5_block4_0_bn
# 335 conv5_block4_0_relu
# 336 conv5_block4_1_conv
# 337 conv5_block4_1_bn
# 338 conv5_block4_1_relu
# 339 conv5_block4_2_conv
# 340 conv5_block4_concat
# 341 conv5_block5_0_bn
# 342 conv5_block5_0_relu
# 343 conv5_block5_1_conv
# 344 conv5_block5_1_bn
# 345 conv5_block5_1_relu
# 346 conv5_block5_2_conv
# 347 conv5_block5_concat
# 348 conv5_block6_0_bn
# 349 conv5_block6_0_relu
# 350 conv5_block6_1_conv
# 351 conv5_block6_1_bn
# 352 conv5_block6_1_relu
# 353 conv5_block6_2_conv
# 354 conv5_block6_concat
# 355 conv5_block7_0_bn
# 356 conv5_block7_0_relu
# 357 conv5_block7_1_conv
# 358 conv5_block7_1_bn
# 359 conv5_block7_1_relu
# 360 conv5_block7_2_conv
# 361 conv5_block7_concat
# 362 conv5_block8_0_bn
# 363 conv5_block8_0_relu
# 364 conv5_block8_1_conv
# 365 conv5_block8_1_bn
# 366 conv5_block8_1_relu
# 367 conv5_block8_2_conv
# 368 conv5_block8_concat
# 369 conv5_block9_0_bn
# 370 conv5_block9_0_relu
# 371 conv5_block9_1_conv
# 372 conv5_block9_1_bn
# 373 conv5_block9_1_relu
# 374 conv5_block9_2_conv
# 375 conv5_block9_concat
# 376 conv5_block10_0_bn
# 377 conv5_block10_0_relu
# 378 conv5_block10_1_conv
# 379 conv5_block10_1_bn
# 380 conv5_block10_1_relu
# 381 conv5_block10_2_conv
# 382 conv5_block10_concat
# 383 conv5_block11_0_bn
# 384 conv5_block11_0_relu
# 385 conv5_block11_1_conv
# 386 conv5_block11_1_bn
# 387 conv5_block11_1_relu
# 388 conv5_block11_2_conv
# 389 conv5_block11_concat
# 390 conv5_block12_0_bn
# 391 conv5_block12_0_relu
# 392 conv5_block12_1_conv
# 393 conv5_block12_1_bn
# 394 conv5_block12_1_relu
# 395 conv5_block12_2_conv
# 396 conv5_block12_concat
# 397 conv5_block13_0_bn
# 398 conv5_block13_0_relu
# 399 conv5_block13_1_conv
# 400 conv5_block13_1_bn
# 401 conv5_block13_1_relu
# 402 conv5_block13_2_conv
# 403 conv5_block13_concat
# 404 conv5_block14_0_bn
# 405 conv5_block14_0_relu
# 406 conv5_block14_1_conv
# 407 conv5_block14_1_bn
# 408 conv5_block14_1_relu
# 409 conv5_block14_2_conv
# 410 conv5_block14_concat
# 411 conv5_block15_0_bn
# 412 conv5_block15_0_relu
# 413 conv5_block15_1_conv
# 414 conv5_block15_1_bn
# 415 conv5_block15_1_relu
# 416 conv5_block15_2_conv
# 417 conv5_block15_concat
# 418 conv5_block16_0_bn
# 419 conv5_block16_0_relu
# 420 conv5_block16_1_conv
# 421 conv5_block16_1_bn
# 422 conv5_block16_1_relu
# 423 conv5_block16_2_conv
# 424 conv5_block16_concat
# 425 bn

# %%
# choose trainable layers as 'Frozen' or 'All' or some number
trainable_layers = 141
# otherwise trainable_layers = x
# add a global spatial average pooling layer to the pretrained model to 
# finish its compilation
def compileModel(trainable_layers = 'Frozen'):
    global Final_model
    x = Model_base.output
    x = GlobalAveragePooling2D()(x)
    # let's add a fully-connected layer
    x = Dense(512, activation='relu')(x)
    preds = Dense(1, activation='sigmoid')(x)
    Final_model = Model(inputs=Model_base.input, outputs=preds)
    if (trainable_layers == 'Frozen'):
        for layer in Model_base.layers:   # only train the new layers first
            layer.trainable = False
    elif (trainable_layers == 'All'):
        for layer in Model_base.layers:   # only train the new layers first
            layer.trainable = True
    else:
        for layer in Model_base.layers[:trainable_layers]:
            layer.trainable = False
        for layer in Model_base.layers[trainable_layers:]:  
            layer.trainable = True
    Final_model.compile(optimizer='rmsprop', loss='binary_crossentropy', 
                            metrics=['accuracy', precision, recall, fmeasure])

# %%
###################### first training stage ###################################
batch_size = 64
step_size = 420
base_lr = 0.00001
max_lr = 0.001
epochs = 48
mode = 'triangular'
def train_Model(verbose =1, times = 2, epochs = epochs, base_lr = base_lr, max_lr= max_lr, mode = mode, 
                stepsize = step_size, batch_size = batch_size, use_tensorboard = False):
    start_time = time()   
    global h
    global no_of_epochs
    global name
    date = str(datetime.now().date())
    # logdir in linux:
    logdir = (log_dir + '/' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + '_base-' 
              + str(base_lr) + '_max-' + str(max_lr) + '_' + str(times))
    # logdir in windows:
    ##logdir = (log_dir + '\\' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + 
    #          '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(times))
    name = ('batch size: ' + str(batch_size) + ', mode: ' + str(mode) + ', stepsize: ' 
            + str(stepsize) + ', base-lr: ' + str(base_lr) + ', max-lr ' + str(max_lr) + ', *' + str(times))
    print(' - Model specifics:\t{}'.format(name))
    clr = CyclicLR(base_lr = base_lr, max_lr=max_lr,
                        step_size= stepsize, mode = mode)
    tbCallBack = TensorBoard(log_dir=logdir, histogram_freq=0, 
                         write_graph=False, write_images=False)
    if (use_tensorboard == True):
        Final_model.fit(x = train_images, y = train_labels, epochs = epochs, callbacks= [tbCallBack, clr], 
                            validation_data = (valid_images, valid_labels), batch_size = batch_size, 
                            verbose = verbose)
    else:
        Final_model.fit(x = train_images, y = train_labels, epochs = epochs, callbacks= [clr], 
                            validation_data = (valid_images, valid_labels), batch_size = batch_size, 
                            verbose = verbose)
    no_of_epochs = no_of_epochs + epochs
    h = []
    h = clr.history
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')
print(weights)
print(trainable_layers)
# Out:
# imagenet
# 141

# %%
compileModel()
train_Model(times = 5, use_tensorboard = True, verbose = 0)
train_acc = round(Final_model.evaluate(train_images, train_labels, 128)[1],4)
valid_acc = round(Final_model.evaluate(valid_images, valid_labels, 128)[1],4)
test_acc = round(Final_model.evaluate(test_images, test_labels, 128)[1],4)

print("- Training accuracy:\t{}".format(train_acc))
print("- Validation accuracy:\t{}".format(valid_acc))
print("- Test accuracy:\t{}".format(test_acc))

# %matplotlib inline
lr = h['lr'][:step_size]
acc = h['acc'][:step_size]
plt.plot(lr, acc)
# Out:
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.001, *5
# Time usage: 0:02:42 minutes
# 3357/3357 [==============================] - 3s 943us/step
# 374/374 [==============================] - 1s 2ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracy:	0.7602
# - Validation accuracy:	0.7193
# - Test accuracy:	0.7323

# %%
### choose your learning rates now! The one where the accuracy starts to rise as base_lr and the one where it stops
### growing/ starts to tumble as max_lr
baseLRS = [0.000001, 0.00001, 0.00005]
maxLRS = [0.0002, 0.0004, 0.0006]

# %%
# experiment with different learning rate ranges
def learning_rate_finder(rep = 5, baseLRS = baseLRS, maxLRS = maxLRS):
    start_time = time() 
    global test_acc_list
    global valid_acc_list
    global train_acc_list
    global test_loss_list
    global valid_loss_list
    global train_loss_list
    global test_prec_list
    global valid_prec_list
    global train_prec_list
    global test_rec_list
    global valid_rec_list
    global train_rec_list
    global model_details
    model_details = []
    test_acc_list = []
    valid_acc_list = []
    train_acc_list = []
    test_loss_list = []
    valid_loss_list = []
    train_loss_list = []
    test_prec_list = []
    valid_prec_list = []
    train_prec_list = []
    test_rec_list = []
    valid_rec_list = []
    train_rec_list = []
    for blr in baseLRS:
        print('NEXT LEARNINGRATE: {}'.format(blr))
        for mlr in maxLRS:
            print('Models with base lr = ' + str(blr) + ' and max lr = ' + str(mlr))
            for i in range(rep):
                    compileModel()
                    times = i
                    if (i == 0):
                        train_Model(times = times, epochs = epochs, base_lr = blr, max_lr = mlr, verbose = 0, 
                                    use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = epochs, base_lr = blr, max_lr = mlr, verbose = 0)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_list.append(test_acc)
                    valid_acc_list.append(valid_acc)
                    train_acc_list.append(train_acc)
                    test_loss_list.append(test_loss)
                    valid_loss_list.append(valid_loss)
                    train_loss_list.append(train_loss)
                    test_prec_list.append(test_prec)
                    valid_prec_list.append(valid_prec)
                    train_prec_list.append(train_prec)
                    test_rec_list.append(test_rec)
                    valid_rec_list.append(valid_rec)
                    train_rec_list.append(train_rec)
                    model_details.append(name)
            print("- Training accuracies:\t{}".format([round(el,4) for el in train_acc_list]))
            print("- Validation accuracies:\t{}".format([round(el,4) for el in valid_acc_list]))
            print("- Testing accuracies:\t{}".format([round(el,4) for el in test_acc_list]))
            print('')
            print('')
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# usual training time: 2h
learning_rate_finder()
# %matplotlib inline
acc = h['acc']
plt.plot(acc)
# Out:
# NEXT LEARNINGRATE: 1e-06
# Models with base lr = 1e-06 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:36 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 1s 2ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:36 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:32 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:37 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:37 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548]
#
#
# Models with base lr = 1e-06 and max lr = 0.0004
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0004, *0
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0004, *1
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0004, *2
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0004, *3
# Time usage: 0:02:25 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0004, *4
# Time usage: 0:02:31 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758]
#
#
# Models with base lr = 1e-06 and max lr = 0.0006
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0006, *0
# Time usage: 0:02:32 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0006, *1
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0006, *2
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0006, *3
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0006, *4
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612]
#
#
# NEXT LEARNINGRATE: 1e-05
# Models with base lr = 1e-05 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *0
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *1
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *2
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *3
# Time usage: 0:02:40 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *4
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757]
#
#
# Models with base lr = 1e-05 and max lr = 0.0004
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0004, *0
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0004, *1
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0004, *2
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0004, *3
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0004, *4
# Time usage: 0:02:26 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801, 0.7861, 0.8049, 0.7858, 0.7834, 0.7906]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594, 0.7567, 0.7754, 0.762, 0.7433, 0.7487]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757, 0.7355, 0.7473, 0.7452, 0.7484, 0.7441]
#
#
# Models with base lr = 1e-05 and max lr = 0.0006
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0006, *0
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0006, *1
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0006, *2
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0006, *3
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0006, *4
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801, 0.7861, 0.8049, 0.7858, 0.7834, 0.7906, 0.7855, 0.7927, 0.7849, 0.7718, 0.7819]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594, 0.7567, 0.7754, 0.762, 0.7433, 0.7487, 0.7487, 0.7433, 0.746, 0.7326, 0.7433]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757, 0.7355, 0.7473, 0.7452, 0.7484, 0.7441, 0.7473, 0.7355, 0.7441, 0.7409, 0.7302]
#
#
# NEXT LEARNINGRATE: 5e-05
# Models with base lr = 5e-05 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *0
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *1
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.120146). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111971). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.113167). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801, 0.7861, 0.8049, 0.7858, 0.7834, 0.7906, 0.7855, 0.7927, 0.7849, 0.7718, 0.7819, 0.7873, 0.773, 0.7858, 0.804, 0.7834]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594, 0.7567, 0.7754, 0.762, 0.7433, 0.7487, 0.7487, 0.7433, 0.746, 0.7326, 0.7433, 0.7487, 0.7433, 0.754, 0.7807, 0.7647]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757, 0.7355, 0.7473, 0.7452, 0.7484, 0.7441, 0.7473, 0.7355, 0.7441, 0.7409, 0.7302, 0.7559, 0.7452, 0.742, 0.7645, 0.7409]
#
#
# Models with base lr = 5e-05 and max lr = 0.0004
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0004, *0
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0004, *1
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0004, *2
# Time usage: 0:02:29 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0004, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.115957). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0004, *4
# Time usage: 0:02:27 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801, 0.7861, 0.8049, 0.7858, 0.7834, 0.7906, 0.7855, 0.7927, 0.7849, 0.7718, 0.7819, 0.7873, 0.773, 0.7858, 0.804, 0.7834, 0.8022, 0.7694, 0.7918, 0.7831, 0.7855]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594, 0.7567, 0.7754, 0.762, 0.7433, 0.7487, 0.7487, 0.7433, 0.746, 0.7326, 0.7433, 0.7487, 0.7433, 0.754, 0.7807, 0.7647, 0.7674, 0.746, 0.7727, 0.7567, 0.7487]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757, 0.7355, 0.7473, 0.7452, 0.7484, 0.7441, 0.7473, 0.7355, 0.7441, 0.7409, 0.7302, 0.7559, 0.7452, 0.742, 0.7645, 0.7409, 0.7677, 0.7334, 0.7559, 0.7334, 0.7377]
#
#
# Models with base lr = 5e-05 and max lr = 0.0006
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.103662). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:28 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.103875). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:32 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.7962, 0.7957, 0.8052, 0.7763, 0.7921, 0.7962, 0.7939, 0.7912, 0.7799, 0.7954, 0.7793, 0.7623, 0.7828, 0.7817, 0.7933, 0.7733, 0.7778, 0.7989, 0.7781, 0.801, 0.7861, 0.8049, 0.7858, 0.7834, 0.7906, 0.7855, 0.7927, 0.7849, 0.7718, 0.7819, 0.7873, 0.773, 0.7858, 0.804, 0.7834, 0.8022, 0.7694, 0.7918, 0.7831, 0.7855, 0.759, 0.7688, 0.7712, 0.776, 0.7891]
# - Validation accuracies:	[0.7701, 0.7567, 0.7647, 0.7701, 0.7513, 0.7567, 0.7594, 0.7406, 0.7273, 0.7594, 0.7487, 0.7219, 0.754, 0.754, 0.746, 0.738, 0.754, 0.754, 0.738, 0.7594, 0.7567, 0.7754, 0.762, 0.7433, 0.7487, 0.7487, 0.7433, 0.746, 0.7326, 0.7433, 0.7487, 0.7433, 0.754, 0.7807, 0.7647, 0.7674, 0.746, 0.7727, 0.7567, 0.7487, 0.7166, 0.7406, 0.7326, 0.7513, 0.746]
# - Testing accuracies:	[0.7666, 0.7623, 0.7623, 0.743, 0.7548, 0.7537, 0.7505, 0.743, 0.7345, 0.758, 0.743, 0.7238, 0.7452, 0.7366, 0.7612, 0.7463, 0.743, 0.7463, 0.742, 0.757, 0.7355, 0.7473, 0.7452, 0.7484, 0.7441, 0.7473, 0.7355, 0.7441, 0.7409, 0.7302, 0.7559, 0.7452, 0.742, 0.7645, 0.7409, 0.7677, 0.7334, 0.7559, 0.7334, 0.7377, 0.7323, 0.7323, 0.7355, 0.742, 0.7463]
#
#
# Time usage: 1:56:22 minutes

# %%
titel = model_details[0][:47]
mean_test_acc = []
mean_valid_acc = []
mean_train_acc = []
mean_test_loss = []
mean_valid_loss = []
mean_train_loss = []
mean_test_prec = []
mean_valid_prec = []
mean_train_prec = []
mean_test_rec = []
mean_valid_rec = []
mean_train_rec = []
model_list = []
a = len(test_acc_list)
for i in range(9):
    tals = test_acc_list[i:(i+1)*5]
    vals = valid_acc_list[i:(i+1)*5]
    rals = train_acc_list[i:(i+1)*5]
    tlls = test_loss_list[i:(i+1)*5]
    vlls = valid_loss_list[i:(i+1)*5]
    rlls = train_loss_list[i:(i+1)*5]
    tpls = test_prec_list[i:(i+1)*5]
    vpls = valid_prec_list[i:(i+1)*5]
    rpls = train_prec_list[i:(i+1)*5]
    trls = test_rec_list[i:(i+1)*5]
    vrls = valid_rec_list[i:(i+1)*5]
    rrls = train_rec_list[i:(i+1)*5]
    tmean = round(sum(tals)/len(tals),4)
    vmean = round(sum(vals)/len(vals),4)
    rmean = round(sum(rals)/len(rals),4)
    ltmean = round(sum(tlls)/len(tals),4)
    lvmean = round(sum(vlls)/len(vals),4)
    lrmean = round(sum(rlls)/len(rals),4)
    ptmean = round(sum(tpls)/len(tals),4)
    pvmean = round(sum(vpls)/len(vals),4)
    prmean = round(sum(rpls)/len(rals),4)
    rtmean = round(sum(trls)/len(tals),4)
    rvmean = round(sum(vrls)/len(vals),4)
    rrmean = round(sum(rrls)/len(rals),4)
    mean_test_acc.append(tmean)
    mean_valid_acc.append(vmean)
    mean_train_acc.append(rmean)
    mean_test_loss.append(ltmean)
    mean_valid_loss.append(lvmean)
    mean_train_loss.append(lrmean)
    mean_test_prec.append(ptmean)
    mean_valid_prec.append(pvmean)
    mean_train_prec.append(prmean)
    mean_test_rec.append(rtmean)
    mean_valid_rec.append(rvmean)
    mean_train_rec.append(rrmean)
    model_list.append(model_details[i*5][49:79])
columns = ['test acc', 'valid acc', 'train acc', 'test loss', 'valid loss', 'train loss', 'test prec', \
           'valid prec', 'train prec', 'test rec', 'valid rec', 'train rec']
data = np.array((mean_test_acc, mean_valid_acc, mean_train_acc, mean_test_loss, mean_valid_loss, mean_train_loss,\
                mean_test_prec, mean_valid_prec, mean_train_prec, mean_test_rec, mean_valid_rec, mean_train_rec))
results = pd.DataFrame(data = data, columns = model_list, index = columns)
lr_overview = pd.DataFrame(data = results.transpose(), columns = columns, index = model_list)
#lr_overview
overviewSorted = lr_overview.sort_values(by=['test acc'], ascending = False)
overviewSorted
# Out:
#                                 test acc  valid acc  train acc  test loss  \
# base-lr: 1e-06, max-lr 0.0002,    0.7578     0.7626     0.7931     1.1919
# base-lr: 1e-06, max-lr 0.0004,    0.7514     0.7540     0.7917     1.4111
# base-lr: 1e-06, max-lr 0.0006,    0.7469     0.7503     0.7869     1.5876
# base-lr: 1e-05, max-lr 0.0002,    0.7460     0.7490     0.7855     1.5445
# base-lr: 1e-05, max-lr 0.0004,    0.7457     0.7499     0.7870     1.5615
# base-lr: 5e-05, max-lr 0.0002,    0.7447     0.7499     0.7859     1.5974
# base-lr: 5e-05, max-lr 0.0004,    0.7447     0.7509     0.7857     1.6106
# base-lr: 1e-05, max-lr 0.0006,    0.7441     0.7484     0.7861     1.6353
# base-lr: 5e-05, max-lr 0.0006,    0.7438     0.7493     0.7838     1.6605
#
#                                 valid loss  train loss  test prec  valid prec  \
# base-lr: 1e-06, max-lr 0.0002,      1.2189      0.9181     0.6926      0.6743
# base-lr: 1e-06, max-lr 0.0004,      1.4505      1.0754     0.6860      0.6672
# base-lr: 1e-06, max-lr 0.0006,      1.6463      1.2135     0.6816      0.6638
# base-lr: 1e-05, max-lr 0.0002,      1.5966      1.1817     0.6804      0.6620
# base-lr: 1e-05, max-lr 0.0004,      1.6110      1.1942     0.6805      0.6630
# base-lr: 5e-05, max-lr 0.0002,      1.6467      1.2258     0.6796      0.6628
# base-lr: 5e-05, max-lr 0.0004,      1.6604      1.2364     0.6795      0.6636
# base-lr: 1e-05, max-lr 0.0006,      1.6867      1.2555     0.6789      0.6616
# base-lr: 5e-05, max-lr 0.0006,      1.7207      1.2811     0.6781      0.6623
#
#                                 train prec  test rec  valid rec  train rec
# base-lr: 1e-06, max-lr 0.0002,      0.7187    0.9530     0.9651     0.9608
# base-lr: 1e-06, max-lr 0.0004,      0.7167    0.9516     0.9601     0.9633
# base-lr: 1e-06, max-lr 0.0006,      0.7110    0.9518     0.9602     0.9660
# base-lr: 1e-05, max-lr 0.0002,      0.7091    0.9534     0.9629     0.9671
# base-lr: 1e-05, max-lr 0.0004,      0.7108    0.9521     0.9623     0.9662
# base-lr: 5e-05, max-lr 0.0002,      0.7091    0.9531     0.9639     0.9673
# base-lr: 5e-05, max-lr 0.0004,      0.7091    0.9531     0.9649     0.9667
# base-lr: 1e-05, max-lr 0.0006,      0.7095    0.9524     0.9627     0.9668
# base-lr: 5e-05, max-lr 0.0006,      0.7069    0.9548     0.9642     0.9677

# %%
blr = 0.000001
mlr = 0.0002

# %%
os.chdir(code_dir + '/Excel')
savename = ('AfterTuningLR_modelOverview_' + str(modelname) + '_bs-' + str(batch_size) + '_' + str(mode) + '_sz-' 
            + str(step_size) + '_' + str(weights) + '_' + str(trainable_layers) + '_' + str(epochs) + 'epochs')
savename
# Out:
# 'AfterTuningLR_modelOverview_DenseNet121_bs-64_triangular_sz-420_imagenet_141_48epochs'

# %%
overviewSorted.to_csv(savename)

# %%
import seaborn as sns
sns.set()
heatmap = sns.heatmap(results.iloc[:3,:].transpose(), annot=True, fmt = 'f')

# %%
# %matplotlib inline

f, (ax1, ax2) = plt.subplots(2, 1, sharex='col', sharey='row')
ax1.plot(mean_test_acc, color = 'r')
ax1.axis([0, 8, 0.5, 1])
ax1.set_title('Close up')
ax1.plot(mean_valid_acc)
ax1.plot(mean_train_acc, color = 'g')
ax2.set_title('Zoom')
ax2.plot(mean_test_acc, color = 'r')
ax2.axis([0, 8, 0.7, 0.8])
ax2.plot(mean_valid_acc)
ax2.plot(mean_train_acc, color = 'g')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
stepsizes128 = [157, 210, 262]
stepsizes64 = [315, 420,525]
batch_sizes = [64, 128]
modes = ['triangular', 'triangular2']
rep = 1

# %%
def hp_tuner(base_lr = base_lr, max_lr = max_lr, rep = 5):
    start_time = time()  
    global test_acc_l
    global valid_acc_l
    global train_acc_l
    global test_loss_l
    global valid_loss_l
    global train_loss_l
    global test_prec_l
    global valid_prec_l
    global train_prec_l
    global test_rec_l
    global valid_rec_l
    global train_rec_l
    global model_det
    model_det = []
    test_acc_l = []
    valid_acc_l = []
    train_acc_l = []
    test_loss_l = []
    valid_loss_l = []
    train_loss_l = []
    test_prec_l = []
    valid_prec_l = []
    train_prec_l = []
    test_rec_l = []
    valid_rec_l = []
    train_rec_l = []
    for bs in batch_sizes:
        if (bs == 64):
            stepsizes = stepsizes64
        if (bs ==128):
            stepsizes = stepsizes128
        for sz in stepsizes: 
            for md in modes:
                i = 0
                mid_time = time()
                while (i < rep):
                    compileModel()
                    times = i
                    if (i == 0):
                        train_Model(times = times, epochs = 48, base_lr = blr, max_lr = mlr, verbose = 0,
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = 48, base_lr = blr, max_lr = mlr, verbose = 0, 
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = False)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_l.append(test_acc)
                    valid_acc_l.append(valid_acc)
                    train_acc_l.append(train_acc)
                    test_loss_l.append(test_loss)
                    valid_loss_l.append(valid_loss)
                    train_loss_l.append(train_loss)
                    test_prec_l.append(test_prec)
                    valid_prec_l.append(valid_prec)
                    train_prec_l.append(train_prec)
                    test_rec_l.append(test_rec)
                    valid_rec_l.append(valid_rec)
                    train_rec_l.append(train_rec)
                    model_det.append(name)
    ### training the same model for more epochs
                    if (i == 0):
                        train_Model(times = times, epochs = 48, base_lr = blr, max_lr = mlr, verbose = 0,
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = 48, base_lr = blr, max_lr = mlr, verbose = 0, 
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = False)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_l.append(test_acc)
                    valid_acc_l.append(valid_acc)
                    train_acc_l.append(train_acc)
                    test_loss_l.append(test_loss)
                    valid_loss_l.append(valid_loss)
                    train_loss_l.append(train_loss)
                    test_prec_l.append(test_prec)
                    valid_prec_l.append(valid_prec)
                    train_prec_l.append(train_prec)
                    test_rec_l.append(test_rec)
                    valid_rec_l.append(valid_rec)
                    train_rec_l.append(train_rec)
                    name2 = name + '_x2'
                    model_det.append(name2)
                    print(log_dir)
                    i += 1
                mid_end_time = time()
                mid_time_dif = mid_end_time - mid_time
                print('Time usage: ' + str(timedelta(seconds=int(round(mid_time_dif)))) + ' minutes')
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# usual training time: 4:51
rep = 5
hp_tuner(rep = rep)
# Out:
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:26 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.100589). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:34 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:27 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:30 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.100069). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:27 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.157146). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:26 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:26:12 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.136946). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:36 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:28 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.136014). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:37 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.140131). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:38 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.131768). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:32 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:31 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.142403). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:35 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:30 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:26:14 minutes
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.166882). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:30 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.143746). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:31 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.130587). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:31 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:27 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.129101). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:38 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.117571). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:36 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:26 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:26:04 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.132427). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:34 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:23 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.118580). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:32 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:31 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.119768). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:36 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:23 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.120056). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:34 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.119338). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:34 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:23 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:25:49 minutes
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.123328). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:36 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:27 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.115829). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:30 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.122789). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:33 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:30 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.128380). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:33 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.121843). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:36 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:25:52 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.126046). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:34 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:27 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.145263). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:39 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.202060). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:39 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:25 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.200640). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:37 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:26 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.199100). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:35 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:28 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:26:10 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.158808). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:14 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:06 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.188352). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.152635). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.152351). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:11 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.151069). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:11 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:22:16 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.183758). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:14 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.167812). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:19 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.170473). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:11 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.153147). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.148330). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:22:22 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.154189). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.151971). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.150554). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.150221). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:24 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.149578). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:22:30 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.152359). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:21 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.183337). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.150630). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:14 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:06 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.167368). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.177465). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:16 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:22:39 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.154668). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:18 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.157276). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:03 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.156642). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.154925). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:13 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.156727). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:12 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:04 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:22:23 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.210810). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:31 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:08 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.209100). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:16 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:06 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.205729). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:16 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.204171). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:15 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.215975). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:21 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:05 minutes
# 374/374 [==============================] - 0s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 4s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:23:04 minutes
# Time usage: 4:51:35 minutes

# %%
rep = 5
titel = model_details[0][:47]
mean_test_a = []
mean_valid_a = []
mean_train_a = []
mean_test_l = []
mean_valid_l = []
mean_train_l = []
mean_test_p = []
mean_valid_p = []
mean_train_p = []
mean_test_r = []
mean_valid_r = []
mean_train_r = []
model_l = []
a = int(len(test_acc_l)/rep)
for i in range(a):
    tals = test_acc_l[i:(i+1)*rep]
    vals = valid_acc_l[i:(i+1)*rep]
    rals = train_acc_l[i:(i+1)*rep]
    tlls = test_loss_l[i:(i+1)*rep]
    vlls = valid_loss_l[i:(i+1)*rep]
    rlls = train_loss_l[i:(i+1)*rep]
    tpls = test_prec_l[i:(i+1)*rep]
    vpls = valid_prec_l[i:(i+1)*rep]
    rpls = train_prec_l[i:(i+1)*rep]
    trls = test_rec_l[i:(i+1)*rep]
    vrls = valid_rec_l[i:(i+1)*rep]
    rrls = train_rec_l[i:(i+1)*rep]
    tmean = round(sum(tals)/len(tals),4)
    vmean = round(sum(vals)/len(vals),4)
    rmean = round(sum(rals)/len(rals),4)
    ltmean = round(sum(tlls)/len(tals),4)
    lvmean = round(sum(vlls)/len(vals),4)
    lrmean = round(sum(rlls)/len(rals),4)
    ptmean = round(sum(tpls)/len(tals),4)
    pvmean = round(sum(vpls)/len(vals),4)
    prmean = round(sum(rpls)/len(rals),4)
    rtmean = round(sum(trls)/len(tals),4)
    rvmean = round(sum(vrls)/len(vals),4)
    rrmean = round(sum(rrls)/len(rals),4)
    mean_test_a.append(tmean)
    mean_valid_a.append(vmean)
    mean_train_a.append(rmean)
    mean_test_l.append(ltmean)
    mean_valid_l.append(lvmean)
    mean_train_l.append(lrmean)
    mean_test_p.append(ptmean)
    mean_valid_p.append(pvmean)
    mean_train_p.append(prmean)
    mean_test_r.append(rtmean)
    mean_valid_r.append(rvmean)
    mean_train_r.append(rrmean)
    if (model_det[i*rep][-2:] == 'x2'):
        model_l.append(model_det[i*rep][6:49] + ' ' + model_det[i*rep][-2:])
    else:
        model_l.append(model_det[i*rep][6:49])

# %%
print(model_det[8][6:49])
print(model_det[0][-2:])
# Out:
# size: 64, mode: triangular, stepsize: 315,
# *0

# %%
savename2 = ('AfterTuningHP_modelOverview_' + str(modelname) + '_bs-'+ str(batch_size) + '_' + str(mode) + '_sz-' 
             + str(step_size) + '_' + str(weights) + '_' + str(trainable_layers) + '_' + str(epochs) + 'epochs')
savename2
# Out:
# 'AfterTuningHP_modelOverview_DenseNet121_bs-64_triangular_sz-420_imagenet_141_48epochs'

# %%
cols = ['test acc', 'valid acc', 'train acc', 'test loss', 'valid loss', 'train loss', 'test prec', \
           'valid prec', 'train prec', 'test rec', 'valid rec', 'train rec']
data2 = np.array((mean_test_a, mean_valid_a, mean_train_a, mean_test_l, mean_valid_l, mean_train_l,\
                mean_test_p, mean_valid_p, mean_train_p, mean_test_r, mean_valid_r, mean_train_r))
results2 = pd.DataFrame(data = data2, columns = model_l, index = cols)
hp_overview = pd.DataFrame(data = results2.transpose(), columns = cols, index = model_l)
hpOverviewSorted = hp_overview.sort_values(by=['test acc'], ascending = False)
hpOverviewSorted
os.chdir(code_dir + '/Excel')
hpOverviewSorted.to_csv(savename2)
# Out:
#                                                 test acc  valid acc  \
# size: 128, mode: triangular, stepsize: 157,       0.7512     0.7570
# size: 128, mode: triangular2, stepsize: 157 x2    0.7511     0.7579
# size: 128, mode: triangular2, stepsize: 262 x2    0.7511     0.7578
# size: 128, mode: triangular2, stepsize: 262       0.7510     0.7573
# size: 128, mode: triangular, stepsize: 210,       0.7509     0.7573
# size: 128, mode: triangular, stepsize: 157, x2    0.7508     0.7570
# size: 128, mode: triangular2, stepsize: 210 x2    0.7508     0.7569
# size: 128, mode: triangular2, stepsize: 210       0.7508     0.7571
# size: 128, mode: triangular, stepsize: 210, x2    0.7508     0.7569
# size: 128, mode: triangular2, stepsize: 157       0.7507     0.7576
# size: 128, mode: triangular, stepsize: 262, x2    0.7507     0.7574
# size: 128, mode: triangular, stepsize: 262,       0.7507     0.7572
# size: 64, mode: triangular2, stepsize: 525, x2    0.7505     0.7562
# size: 64, mode: triangular2, stepsize: 525,       0.7502     0.7556
# size: 64, mode: triangular2, stepsize: 315, x2    0.7497     0.7550
# size: 64, mode: triangular, stepsize: 420,        0.7494     0.7554
# size: 64, mode: triangular2, stepsize: 420,       0.7494     0.7531
# size: 64, mode: triangular2, stepsize: 315,       0.7493     0.7524
# size: 64, mode: triangular2, stepsize: 420, x2    0.7491     0.7543
# size: 64, mode: triangular, stepsize: 420,  x2    0.7489     0.7537
# size: 64, mode: triangular, stepsize: 525,        0.7486     0.7548
# size: 64, mode: triangular, stepsize: 525,  x2    0.7484     0.7548
# size: 64, mode: triangular, stepsize: 315,        0.7478     0.7535
# size: 64, mode: triangular, stepsize: 315,  x2    0.7476     0.7540
#
#                                                 train acc  test loss  \
# size: 128, mode: triangular, stepsize: 157,        0.7900     1.3034
# size: 128, mode: triangular2, stepsize: 157 x2     0.7902     1.2970
# size: 128, mode: triangular2, stepsize: 262 x2     0.7901     1.3164
# size: 128, mode: triangular2, stepsize: 262        0.7896     1.3208
# size: 128, mode: triangular, stepsize: 210,        0.7898     1.3072
# size: 128, mode: triangular, stepsize: 157, x2     0.7900     1.3211
# size: 128, mode: triangular2, stepsize: 210 x2     0.7895     1.3124
# size: 128, mode: triangular2, stepsize: 210        0.7893     1.3174
# size: 128, mode: triangular, stepsize: 210, x2     0.7895     1.3251
# size: 128, mode: triangular2, stepsize: 157        0.7902     1.3088
# size: 128, mode: triangular, stepsize: 262, x2     0.7893     1.3317
# size: 128, mode: triangular, stepsize: 262,        0.7894     1.3209
# size: 64, mode: triangular2, stepsize: 525, x2     0.7891     1.3076
# size: 64, mode: triangular2, stepsize: 525,        0.7890     1.3031
# size: 64, mode: triangular2, stepsize: 315, x2     0.7876     1.2821
# size: 64, mode: triangular, stepsize: 420,         0.7880     1.2904
# size: 64, mode: triangular2, stepsize: 420,        0.7889     1.2875
# size: 64, mode: triangular2, stepsize: 315,        0.7877     1.3205
# size: 64, mode: triangular2, stepsize: 420, x2     0.7888     1.2882
# size: 64, mode: triangular, stepsize: 420,  x2     0.7881     1.3196
# size: 64, mode: triangular, stepsize: 525,         0.7879     1.3075
# size: 64, mode: triangular, stepsize: 525,  x2     0.7881     1.3272
# size: 64, mode: triangular, stepsize: 315,         0.7852     1.4260
# size: 64, mode: triangular, stepsize: 315,  x2     0.7863     1.4720
#
#                                                 valid loss  train loss  \
# size: 128, mode: triangular, stepsize: 157,         1.3277      1.0052
# size: 128, mode: triangular2, stepsize: 157 x2      1.3199      1.0027
# size: 128, mode: triangular2, stepsize: 262 x2      1.3410      1.0234
# size: 128, mode: triangular2, stepsize: 262         1.3458      1.0276
# size: 128, mode: triangular, stepsize: 210,         1.3322      1.0121
# size: 128, mode: triangular, stepsize: 157, x2      1.3486      1.0198
# size: 128, mode: triangular2, stepsize: 210 x2      1.3397      1.0196
# size: 128, mode: triangular2, stepsize: 210         1.3449      1.0224
# size: 128, mode: triangular, stepsize: 210, x2      1.3543      1.0274
# size: 128, mode: triangular2, stepsize: 157         1.3332      1.0111
# size: 128, mode: triangular, stepsize: 262, x2      1.3576      1.0353
# size: 128, mode: triangular, stepsize: 262,         1.3476      1.0273
# size: 64, mode: triangular2, stepsize: 525, x2      1.3311      1.0086
# size: 64, mode: triangular2, stepsize: 525,         1.3233      1.0060
# size: 64, mode: triangular2, stepsize: 315, x2      1.3027      0.9804
# size: 64, mode: triangular, stepsize: 420,          1.3076      0.9867
# size: 64, mode: triangular2, stepsize: 420,         1.3126      0.9884
# size: 64, mode: triangular2, stepsize: 315,         1.3486      1.0106
# size: 64, mode: triangular2, stepsize: 420, x2      1.3164      0.9940
# size: 64, mode: triangular, stepsize: 420,  x2      1.3449      1.0085
# size: 64, mode: triangular, stepsize: 525,          1.3329      1.0099
# size: 64, mode: triangular, stepsize: 525,  x2      1.3521      1.0250
# size: 64, mode: triangular, stepsize: 315,          1.4853      1.1074
# size: 64, mode: triangular, stepsize: 315,  x2      1.5098      1.1218
#
#                                                 test prec  valid prec  \
# size: 128, mode: triangular, stepsize: 157,        0.6876      0.6706
# size: 128, mode: triangular2, stepsize: 157 x2     0.6882      0.6712
# size: 128, mode: triangular2, stepsize: 262 x2     0.6887      0.6711
# size: 128, mode: triangular2, stepsize: 262        0.6883      0.6705
# size: 128, mode: triangular, stepsize: 210,        0.6879      0.6706
# size: 128, mode: triangular, stepsize: 157, x2     0.6873      0.6704
# size: 128, mode: triangular2, stepsize: 210 x2     0.6878      0.6700
# size: 128, mode: triangular2, stepsize: 210        0.6876      0.6702
# size: 128, mode: triangular, stepsize: 210, x2     0.6877      0.6701
# size: 128, mode: triangular2, stepsize: 157        0.6873      0.6710
# size: 128, mode: triangular, stepsize: 262, x2     0.6879      0.6705
# size: 128, mode: triangular, stepsize: 262,        0.6880      0.6704
# size: 64, mode: triangular2, stepsize: 525, x2     0.6866      0.6697
# size: 64, mode: triangular2, stepsize: 525,        0.6863      0.6691
# size: 64, mode: triangular2, stepsize: 315, x2     0.6843      0.6680
# size: 64, mode: triangular, stepsize: 420,         0.6841      0.6685
# size: 64, mode: triangular2, stepsize: 420,        0.6846      0.6665
# size: 64, mode: triangular2, stepsize: 315,        0.6840      0.6667
# size: 64, mode: triangular2, stepsize: 420, x2     0.6842      0.6674
# size: 64, mode: triangular, stepsize: 420,  x2     0.6840      0.6672
# size: 64, mode: triangular, stepsize: 525,         0.6838      0.6676
# size: 64, mode: triangular, stepsize: 525,  x2     0.6844      0.6681
# size: 64, mode: triangular, stepsize: 315,         0.6816      0.6656
# size: 64, mode: triangular, stepsize: 315,  x2     0.6812      0.6675
#
#                                                 train prec  test rec  \
# size: 128, mode: triangular, stepsize: 157,         0.7154    0.9477
# size: 128, mode: triangular2, stepsize: 157 x2      0.7159    0.9456
# size: 128, mode: triangular2, stepsize: 262 x2      0.7163    0.9443
# size: 128, mode: triangular2, stepsize: 262         0.7156    0.9454
# size: 128, mode: triangular, stepsize: 210,         0.7154    0.9458
# size: 128, mode: triangular, stepsize: 157, x2      0.7153    0.9472
# size: 128, mode: triangular2, stepsize: 210 x2      0.7151    0.9458
# size: 128, mode: triangular2, stepsize: 210         0.7148    0.9467
# size: 128, mode: triangular, stepsize: 210, x2      0.7150    0.9463
# size: 128, mode: triangular2, stepsize: 157         0.7156    0.9472
# size: 128, mode: triangular, stepsize: 262, x2      0.7152    0.9458
# size: 128, mode: triangular, stepsize: 262,         0.7153    0.9456
# size: 64, mode: triangular2, stepsize: 525, x2      0.7141    0.9492
# size: 64, mode: triangular2, stepsize: 525,         0.7141    0.9487
# size: 64, mode: triangular2, stepsize: 315, x2      0.7118    0.9512
# size: 64, mode: triangular, stepsize: 420,          0.7121    0.9507
# size: 64, mode: triangular2, stepsize: 420,         0.7134    0.9495
# size: 64, mode: triangular2, stepsize: 315,         0.7121    0.9508
# size: 64, mode: triangular2, stepsize: 420, x2      0.7131    0.9499
# size: 64, mode: triangular, stepsize: 420,  x2      0.7125    0.9497
# size: 64, mode: triangular, stepsize: 525,          0.7120    0.9504
# size: 64, mode: triangular, stepsize: 525,  x2      0.7130    0.9491
# size: 64, mode: triangular, stepsize: 315,          0.7083    0.9547
# size: 64, mode: triangular, stepsize: 315,  x2      0.7095    0.9546
#
#                                                 valid rec  train rec
# size: 128, mode: triangular, stepsize: 157,        0.9613     0.9614
# size: 128, mode: triangular2, stepsize: 157 x2     0.9617     0.9606
# size: 128, mode: triangular2, stepsize: 262 x2     0.9614     0.9595
# size: 128, mode: triangular2, stepsize: 262        0.9619     0.9600
# size: 128, mode: triangular, stepsize: 210,        0.9621     0.9607
# size: 128, mode: triangular, stepsize: 157, x2     0.9615     0.9615
# size: 128, mode: triangular2, stepsize: 210 x2     0.9622     0.9605
# size: 128, mode: triangular2, stepsize: 210        0.9626     0.9611
# size: 128, mode: triangular, stepsize: 210, x2     0.9624     0.9611
# size: 128, mode: triangular2, stepsize: 157        0.9619     0.9614
# size: 128, mode: triangular, stepsize: 262, x2     0.9625     0.9604
# size: 128, mode: triangular, stepsize: 262,        0.9623     0.9604
# size: 64, mode: triangular2, stepsize: 525, x2     0.9623     0.9626
# size: 64, mode: triangular2, stepsize: 525,        0.9627     0.9629
# size: 64, mode: triangular2, stepsize: 315, x2     0.9659     0.9642
# size: 64, mode: triangular, stepsize: 420,         0.9659     0.9650
# size: 64, mode: triangular2, stepsize: 420,        0.9618     0.9640
# size: 64, mode: triangular2, stepsize: 315,        0.9616     0.9648
# size: 64, mode: triangular2, stepsize: 420, x2     0.9633     0.9639
# size: 64, mode: triangular, stepsize: 420,  x2     0.9631     0.9641
# size: 64, mode: triangular, stepsize: 525,         0.9652     0.9645
# size: 64, mode: triangular, stepsize: 525,  x2     0.9629     0.9635
# size: 64, mode: triangular, stepsize: 315,         0.9678     0.9681
# size: 64, mode: triangular, stepsize: 315,  x2     0.9645     0.9673

# %%
# %matplotlib inline
plt.figure(figsize=(6, 8))

sns.heatmap(hp_overview.iloc[:,:3], annot=True,  fmt = 'f')

# %%
# %matplotlib inline

f, (ax1, ax2) = plt.subplots(2, 1, sharex='col', sharey='row')
ax1.plot(mean_test_a, color = 'r')
ax1.axis([0, 9, 0.5, 1])
ax1.set_title('Close up')
ax1.plot(mean_valid_a)
ax1.plot(mean_train_a, color = 'g')
ax2.set_title('Zoom')
ax2.plot(mean_test_a, color = 'r')
ax2.axis([0, 9, 0.73, 0.79])
ax2.plot(mean_valid_a)
ax2.plot(mean_train_a, color = 'g')
# Out:
# [0, 9, 0.5, 1]
# Text(0.5,1,'Close up')
# Text(0.5,1,'Zoom')
# [0, 9, 0.73, 0.79]

# %%
hp_overview.sort_values(by=['test acc'], ascending = False).iloc[:3,:]
# hp_overview.sort_values(by=['test loss'], ascending = True).iloc[:3,:]
# hp_overview.sort_values(by=['test prec'], ascending = False).iloc[:3,:]
# hp_overview.sort_values(by=['test rec'], ascending = False).iloc[:3,:]
model_det[0][49:79]
# Out:
#                                                 test acc  valid acc  \
# size: 128, mode: triangular, stepsize: 157,       0.7512     0.7570
# size: 128, mode: triangular2, stepsize: 157 x2    0.7511     0.7579
# size: 128, mode: triangular2, stepsize: 262 x2    0.7511     0.7578
#
#                                                 train acc  test loss  \
# size: 128, mode: triangular, stepsize: 157,        0.7900     1.3034
# size: 128, mode: triangular2, stepsize: 157 x2     0.7902     1.2970
# size: 128, mode: triangular2, stepsize: 262 x2     0.7901     1.3164
#
#                                                 valid loss  train loss  \
# size: 128, mode: triangular, stepsize: 157,         1.3277      1.0052
# size: 128, mode: triangular2, stepsize: 157 x2      1.3199      1.0027
# size: 128, mode: triangular2, stepsize: 262 x2      1.3410      1.0234
#
#                                                 test prec  valid prec  \
# size: 128, mode: triangular, stepsize: 157,        0.6876      0.6706
# size: 128, mode: triangular2, stepsize: 157 x2     0.6882      0.6712
# size: 128, mode: triangular2, stepsize: 262 x2     0.6887      0.6711
#
#                                                 train prec  test rec  \
# size: 128, mode: triangular, stepsize: 157,         0.7154    0.9477
# size: 128, mode: triangular2, stepsize: 157 x2      0.7159    0.9456
# size: 128, mode: triangular2, stepsize: 262 x2      0.7163    0.9443
#
#                                                 valid rec  train rec
# size: 128, mode: triangular, stepsize: 157,        0.9613     0.9614
# size: 128, mode: triangular2, stepsize: 157 x2     0.9617     0.9606
# size: 128, mode: triangular2, stepsize: 262 x2     0.9614     0.9595
# 'base-lr: 1e-06, max-lr 0.0002,'

# %%
# decide on best hyperparameters
batch_size = 128
step_size = 157
mode = 'triangular'
base_lr = 0.000001
max_lr = 0.0002
epochs = 48
d3 = {}

# %%
def trainModels(batch_size = batch_size, stepsize = step_size, mode = mode, max_lr = max_lr, base_lr = base_lr, 
                epochs = epochs, verbose = 0):
    start_time = time()   
    global name
    global filepath
    global d    
    date = str(datetime.now().date())
    d = {}
    for i in range(5):
        compileModel()
        # logdir in linux:
        logdir = (log_dir + '/' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) 
                  + '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(i))
        # logdir in windows:
        ##logdir = (log_dir + '\\' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + 
        #          '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(i))
        name = ('batch size: ' + str(batch_size) + ', mode: ' + str(mode) + ', stepsize: ' 
                + str(stepsize) + ', base-lr: ' + str(base_lr) + ', max-lr ' + str(max_lr) + '_' + str(i))
        print(' - Model specifics:\t{}'.format(name))
        clr = CyclicLR(base_lr = base_lr, max_lr=max_lr, step_size= stepsize, mode = mode)
        fp = (str(modelname) + '_bs-' + str(batch_size) + '_' + str(mode) + '_sz-' + str(step_size) + '_blr-' 
              + str(base_lr) + '_mlr-' + str(max_lr) + '_e-' + str(epochs) + '_' + weights + '_' 
              + str(trainable_layers) + '_' + str(i))
        filepath = new_weight_dir + '/' + fp + '-{epoch:02d}-' +'.hdf5'
        checkp = ModelCheckpoint(filepath, monitor='val_acc', verbose= verbose, save_weights_only=True, 
                                save_best_only=True, mode='max', period=1)
        tbCallBack = TensorBoard(log_dir=logdir, histogram_freq=0, 
                             write_graph=False, write_images=False)
        d["FinalModel{0}".format(i)]= Final_model
        d["FinalModel{0}".format(i)].fit(x = train_images, y = train_labels, epochs = epochs, 
                                         callbacks= [tbCallBack, clr, checkp], batch_size = batch_size,
                                         validation_data = (valid_images, valid_labels), verbose = 0)
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# build best model again
# usual time: 15 minutes - 18 - 15 - 13
fm = ['FinalModel1', 'FinalModel2', 'FinalModel3', 'FinalModel4', 'FinalModel5']
metrics = ['loss', 'acc', 'precision', 'recall']
name = ('bs-' + str(batch_size) + '_' + str(mode) + '_sz-' + str(step_size) + '_blr-' + str(base_lr) + '_mlr-' 
       + str(max_lr)) + '_' + str(weights) + '_' + str(trainable_layers)
trainModels(base_lr = base_lr, max_lr= max_lr, epochs = epochs, verbose = 0,
           batch_size = batch_size, stepsize = step_size, mode = mode)
# Out:
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002_0
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002_1
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002_2
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002_3
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 1e-06, max-lr 0.0002_4
# Time usage: 0:12:17 minutes

# %%
# find out where 'bs' starts and '_' ends...
i = 0
last = 122
print(str(filepath)[46:last] + str(i) + str(filepath)[(last+1):])
filename = str(filepath)[46:last] + str(i)
print(filename)
from collections import OrderedDict
# Out:
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_0-{epoch:02d}-.hdf5
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_0

# %%
# usual time: 2 minutes
startTime = time()
FinalModelList = OrderedDict()
d3 = OrderedDict()
for i in range(5):
    filename = str(filepath)[46:last] + str(i) #+ str(filepath)[113:]
    weightlist = os.listdir(new_weight_dir)
    print(filename)
    best_filename = 'no'
    for el in weightlist:
        if(str(el)[:len(filename)]) == filename:
            if len(el)>(len(filename)+5):
                best_filename = el
    print(best_filename)
    best = str(best_filename)[-8:-6]
    os.chdir(new_weight_dir)
    compileModel()
    Final_model.load_weights(best_filename)
    FinalModelList["FinalModel{}-e{}".format(i,best)]= Final_model
    test_m = Final_model.evaluate(test_images, test_labels, verbose = 0)
    test_m = [round(el, 4) for el in test_m]
    valid_m = Final_model.evaluate(valid_images, valid_labels, verbose = 0)
    valid_m = [round(el, 4) for el in valid_m]
    train_m = Final_model.evaluate(train_images, train_labels, verbose = 0)
    train_m = [round(el, 4) for el in train_m]
    col = ["FinalModel{}-e{}".format(i,best)]
    print("td{}-e{}".format(i, best))
    d3["td{}-e{}".format(i, best)]= pd.DataFrame(data = test_m[:4], columns = col, index = metrics)
    print('')
endTime = time()
finalTime = endTime - startTime
print('Time usage: ' + str(timedelta(seconds=int(round(finalTime)))) + ' minutes')
# Out:
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_0
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_0-17-.hdf5
# td0-e17
#
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_1
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_1-26-.hdf5
# td1-e26
#
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_2
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_2-30-.hdf5
# td2-e30
#
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_3
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_3-17-.hdf5
# td3-e17
#
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_4
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_4-19-.hdf5
# td4-e19
#
# Time usage: 0:00:51 minutes

# %%
keys = d3.keys()
FinalResults = pd.concat([d3[keys[0]], d3[keys[1]], d3[keys[2]], d3[keys[3]], d3[keys[4]]], axis=1)
FinalResults = pd.DataFrame(data = FinalResults.transpose(), columns = metrics)
FinalResults.sort_values(by = ['acc'], ascending = False)
# Out:
#                    loss     acc  precision  recall
# FinalModel2-e30  0.8960  0.7719     0.7316  0.8834
# FinalModel3-e17  0.8931  0.7709     0.7211  0.9113
# FinalModel4-e19  0.8566  0.7709     0.7244  0.8968
# FinalModel0-e17  0.8725  0.7634     0.7175  0.8913
# FinalModel1-e26  0.8144  0.7580     0.7115  0.8964

# %%
dictlist = FinalModelList.keys()
print(dictlist)
models = [FinalModelList[dictlist[0]], FinalModelList[dictlist[1]], FinalModelList[dictlist[2]], \
          FinalModelList[dictlist[3]], FinalModelList[dictlist[4]]]
def ensemble(models):    
    global eModel
    outputs = [model.outputs[0] for model in models]
    y = keras.layers.Average()(outputs)   
    eModel = Model(inputs=Model_base.input, outputs = y, name='ensemble')  
    eModel.compile(optimizer='rmsprop', loss='binary_crossentropy',
                   metrics=['accuracy', precision, recall, fmeasure])
    return eModel
ensemble_model = ensemble(models)
ensResults = ensemble_model.evaluate(test_images, test_labels)
Res = pd.DataFrame(data = ensResults[:4], columns = ['ensembleModel'], index = metrics)
Res.transpose()
keys = d3.keys()
FinalResults = pd.concat([d3[keys[0]], d3[keys[1]], d3[keys[2]], d3[keys[3]], d3[keys[4]], Res], axis=1)
FinalResults = pd.DataFrame(data = FinalResults.transpose(), columns = metrics)
FinalResults.sort_values(by = ['acc'], ascending = False)
# Out:
# ['FinalModel0-e17', 'FinalModel1-e26', 'FinalModel2-e30', 'FinalModel3-e17', 'FinalModel4-e19']
# 934/934 [==============================] - 4s 4ms/step
#                      loss       acc  precision    recall
# FinalModel2-e30  0.896000  0.771900   0.731600  0.883400
# FinalModel3-e17  0.893100  0.770900   0.721100  0.911300
# FinalModel4-e19  0.856600  0.770900   0.724400  0.896800
# ensembleModel    0.779209  0.770878   0.725219  0.898597
# FinalModel0-e17  0.872500  0.763400   0.717500  0.891300
# FinalModel1-e26  0.814400  0.758000   0.711500  0.896400

# %%
# change again the path name
# saving the model   
i = 2
#FinName = str(filepath)[46:112] + '_ensemble' 
FinName = str(filepath)[46:last] + str(i) + dictlist[i][-4:]
print(FinName)
os.chdir(model_dir)
#Final_model1 = ensemble_model # or
Final_model = FinalModelList[dictlist[i]]
# predictions = np.round(Final_model.predict(test_images),4)           
# predictions_ensemble = np.round(Final_model1.predict(test_images),4)
# for v1, v2 in zip(predictions[:5], predictions_ensemble[:5]):
#     print('Best model prediction and ensemble prediction: \t{} \t{}'.format(v1, v2))
# Out:
# DenseNet121_bs-128_triangular_sz-157_blr-1e-06_mlr-0.0002_e-48_imagenet_141_2-e30

# %%
Final_model.save(FinName)

# %%
# calculating the ROC    
y_pred = Final_model.predict(test_images, batch_size = 64)
y_true = test_labels
fpr, tpr, thresholds = roc_curve(y_true, y_pred, pos_label = 1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='lime',
         lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='darkgrey', lw=2, linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# calculating the ROC    
y_pred = Final_model.predict(test_images, batch_size = 64)
y_true = test_labels
fpr, tpr, thresholds = roc_curve(y_true, y_pred, pos_label = 1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='lime',
         lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='darkgrey', lw=2, linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Curve')
plt.legend(loc="lower right")
plt.show()

# evaluation with bootstrapping
seed(1)
ratio = 0.1
y_pred_1 = Final_model.predict(test_images, batch_size = 64).squeeze(axis = 1)
def subsample(dataset = y_pred_1, labels = test_labels, ratio= ratio):
    pred_sample = list()
    label_sample = list()
    n_sample = round(len(dataset) * ratio)
    index = sample(range(len(dataset)), n_sample)
    pred_sample = dataset[index]
    label_sample = labels[index]           
    return pred_sample, label_sample

loss = []
accuracy = []
precisions = []
recalls = []
f_measures = []
    
def bootstrap(iterations = 20, ratio = ratio, dataset = y_pred_1, labels = test_labels):    
    for i in range (iterations):
        b_pred, b_labels = subsample(dataset, labels, ratio)
        lo = cross_entropy(b_pred, b_labels)
        b_pred_rounded = b_pred.round()
        acc = accuracy_score(b_labels, b_pred_rounded)
        pre = precision_score(b_labels, b_pred_rounded)
        rec = recall_score(b_labels, b_pred_rounded)
        fme = f1_score(b_labels, b_pred_rounded)
        loss.append(lo)
        accuracy.append(acc)
        precisions.append(pre)
        recalls.append(rec)
        f_measures.append(fme)
        if (i%100 == 0): 
            print('Iteration_' + str(i))
        
bootstrap(iterations = 10000)
plt.hist(accuracy, bins = 100, range = [0,1])
plt.hist(precisions, bins = 100, range = [0,1])
plt.hist(recalls, bins = 100, range = [0,1])
plt.hist(loss, bins = 100)

##################### second training stage ###################################
for i, layer in enumerate(Model_base.layers):
   if ('mix' in layer.name):
       print(i, layer.name)
for layer in Final_model.layers[:275]:
   layer.trainable = False
for layer in Final_model.layers[275:]:
   layer.trainable = True

Final_model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), 
              loss='binary_crossentropy', metrics = ['acc'])
def train2_IncResNet_model(epochs = 21):
    global no_of_epochs
    Final_model.fit(x = train_images, y = train_labels, epochs = epochs)
    no_of_epochs = no_of_epochs + epochs
train2_IncResNet_model(epochs = 21)

result = Final_model.evaluate(test_images, test_labels)
for name, value in zip(Final_model.metrics_names, result):
    print(name, value)

### making predictions on the test data
predictions = Final_model.predict(test_images).squeeze(axis = 1)
binary_preds = predictions.round()
print(predictions[0:10], binary_preds[0:10])

# Plot a few images to see if the data is correct
images = test_images[9:18]
cls_true = test_labels[9:18].astype(int)
plot_images(images=images, cls_true=cls_true)
cls_pred = binary_preds[9:18]
plot_images(images=images, cls_true=cls_true, cls_pred = cls_pred)    

### checking test accuracy, example errors and confusion matrix
print_test_accuracy

### checking which layers are convolutional layers
for i, layer in enumerate(Model_base.layers):
   if ('conv' in layer.name):
       print(i, layer.name)

plot_weights(input_channel = 0, layer_index = 1)
plot_weights(input_channel = 1, layer_index = 1)


















#*****************************************************************************
################# HELPER FUNCTIONS ###########################################
#
#*****************************************************************************

### Helper function for confusion matrix #####################################
import itertools
classes = ['no sp', 'sp']

def plot_confusion_matrix(cm = cm, classes = classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum()
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")     
    plt.tight_layout(pad = 2)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


###### Helper function for plotting images ####################################
def plot_images(images, cls_true, cls_pred=None):
    assert len(images) == len(cls_true) == 9
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i], cmap='binary')
        if cls_pred is None:
            xlabel = "Label: {0}".format(cls_true[i])
        else:
            xlabel = "Label: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])
        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show() 
    
### Example errors
def plot_example_errors(cls_pred, correct):
    incorrect = (correct == False)
    images = test_images[incorrect]
    cls_pred = cls_pred[incorrect]
    cls_true = test_labels[incorrect]
    plot_images(images=images[0:9],
                cls_true=cls_true[0:9],
                cls_pred=cls_pred[0:9])

def print_test_accuracy(show_example_errors=True,
                        show_confusion_matrix=True, 
                        show_first_10_preds = True):
    num_test = len(test_images)
    #cls_pred = np.zeros(shape=num_test, dtype=np.int)
    cls_pred = Final_model.predict(test_images).squeeze(axis = 1).round()
    cls_true = test_labels
    correct = (cls_true == cls_pred)
    correct_sum = correct.sum()
    acc = float(correct_sum) / num_test
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))
    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)
    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        cm = confusion_matrix(test_labels, cls_pred.round())
        plot_confusion_matrix(cm = cm)
    # Show the first hundred predictions made:
    if show_first_10_preds:
        print("First 10 predictions:")
        print(cls_pred[0:10])


#### Helper function for plotting the output of a convolutional layer
#def plot_conv_layer(layer, image):
#    feed_dict = {x: [image]}
#    values = IncResNet_model.run(layer, feed_dict=feed_dict)
#    num_filters = values.shape[3]
#    num_grids = math.ceil(math.sqrt(num_filters))
#    fig, axes = plt.subplots(num_grids, num_grids)
#    for i, ax in enumerate(axes.flat):
#        if i<num_filters:
#            img = values[0, :, :, i]
#            ax.imshow(img, interpolation='nearest', cmap='binary')
#        ax.set_xticks([])
#        ax.set_yticks([])
#    plt.show()

### Helper function for conv weights
def plot_weights(input_channel=0, layer_index = 1):
    w = Final_model.layers[layer_index].get_weights()[0]
    w_min = np.min(w)
    w_max = np.max(w)
    num_filters = w.shape[3]
    num_grids = math.ceil(math.sqrt(num_filters))
    fig, axes = plt.subplots(num_grids, num_grids)
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            img = w[:, :, input_channel, i]
            ax.imshow(img, vmin=w_min, vmax=w_max,
                      interpolation='nearest', cmap='seismic')
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()
