# %%
"""DenseNet models for Keras.
# Reference paper
- [Densely Connected Convolutional Networks]
  (https://arxiv.org/abs/1608.06993) (CVPR 2017 Best Paper Award)
# Reference implementation
- [Torch DenseNets]
  (https://github.com/liuzhuang13/DenseNet/blob/master/models/densenet.lua)
- [TensorNets]
  (https://github.com/taehoonlee/tensornets/blob/master/tensornets/densenets.py)
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

### setting the different directories 

# on the server (linux):
# where to find the images:
home_dir = '/home/rick/Documents/HannahZ'
# folder where to save code and so on
code_dir = home_dir + '/Code'
# where to save the final models
model_dir = code_dir + '/Final_models'
# where to save the logs for visualization in TensorBoard
log_dir = code_dir + '/logs'
# where to save the weights
weight_dir = code_dir + '/weights'


# on my computer (windows):
# where to find the images:
#home_dir = '\\Users\\ThinkPad User\\Google Drive\\DeepSolaris'
# folder where to save code and so on
#code_dir = '\\Users\\ThinkPad User\\Google Drive\\Master_thesis_H_Z_DL&NN\\Coding'
# where to save the final models
#model_dir = code_dir + '\\Final_models_saved'
# where to save the logs for visualization in TensorBoard
#log_dir = code_dir + '\\logs'
import os
os.chdir(home_dir)

# %%
from keras import backend as K
from keras.models import Model
from keras.layers import Activation
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import ZeroPadding2D
from keras.utils.data_utils import get_file
from keras.engine import get_source_inputs
from keras.applications import imagenet_utils
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import _obtain_input_shape 

from sklearn.model_selection import cross_validate
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.losses import binary_crossentropy


from random import randrange
from random import seed
from random import sample
import tensorflow as tf


import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from time import time
from datetime import timedelta
import math
from sklearn.model_selection import train_test_split
from datetime import datetime
from keras.preprocessing import image
from keras.optimizers import SGD
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import keras
from keras.callbacks import Callback
from keras.applications import xception

os.chdir(code_dir)

from Learning_rate_scheduler import LrReducer
from CyclicLR import CyclicLR
# Out:
# Using TensorFlow backend.

# %%
### Helper metrics functions

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
    
def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
    
    
def fbeta_score(y_true, y_pred, beta=1):
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score
def fmeasure(y_true, y_pred):
    return fbeta_score(y_true, y_pred, beta=1)

no_of_epochs = 0

### check if data are in the right format
K.image_data_format() == 'channels_last'

os.chdir(home_dir)
train_images = np.load('training_images_AcMüDüHo.npy')
valid_images = np.load('validation_images_AcMüDüHo.npy')
test_images = np.load('test_images_AcMüDüHo.npy')
train_labels = np.load('training_labels_AcMüDüHo.npy')
valid_labels = np.load('validation_labels_AcMüDüHo.npy')
test_labels = np.load('test_labels_AcMüDüHo.npy')

print("Size of:")
print("- Training-set:\t\t{}".format(len(train_labels)))
print("- Validation-set:\t{}".format(len(valid_labels)))
print("- Test-set:\t\t{}".format(len(test_labels)))
# Out:
# Size of:
# - Training-set:		3357
# - Validation-set:	374
# - Test-set:		934

# %%
# choose training specifications (None or 'imagenet')
weights = None
#tf.reset_default_graph()

# importing the currently used model
os.chdir(code_dir)

### create the base pre-trained model
# usually takes around 30 seconds
Model_base = xception.Xception(weights = weights, include_top=False)
# find out how many layers exist to find right number of trainable layers
len(Model_base.layers)
# Out:
# 132

# %%
# choose layers for split
for i, layer in enumerate(Model_base.layers):
      if ('add' in layer.name):
        print(i, layer.name)
# Out:
# 15 add_1
# 25 add_2
# 35 add_3
# 45 add_4
# 55 add_5
# 65 add_6
# 75 add_7
# 85 add_8
# 95 add_9
# 105 add_10
# 115 add_11
# 125 add_12

# %%
# choose trainable layers as 'Frozen' or 'All' or some number
trainable_layers = 'All'
# otherwise trainable_layers = x
# add a global spatial average pooling layer to the pretrained model to 
# finish its compilation
def compileModel(trainable_layers = 'Frozen'):
    global Final_model
    x = Model_base.output
    x = GlobalAveragePooling2D()(x)
    # let's add a fully-connected layer
    x = Dense(512, activation='relu')(x)
    preds = Dense(1, activation='sigmoid')(x)
    Final_model = Model(inputs=Model_base.input, outputs=preds)
    if (trainable_layers == 'Frozen'):
        for layer in Model_base.layers:   # only train the new layers first
            layer.trainable = False
    elif (trainable_layers == 'All'):
        for layer in Model_base.layers:   # only train the new layers first
            layer.trainable = True
    else:
        for layer in Model_base.layers[:trainable_layers]:
            layer.trainable = False
        for layer in Model_base.layers[trainable_layers:]:  
            layer.trainable = True
    Final_model.compile(optimizer='rmsprop', loss='binary_crossentropy', 
                            metrics=['accuracy', precision, recall, fmeasure])
# calculating the stepsize
(3357/64)*8
# Out:
# 419.625

# %%
###################### first training stage ###################################
batch_size = 64
step_size = 420
base_lr = 0.00001
max_lr = 0.001
epochs = 48
mode = 'triangular'
def train_Model(verbose =1, times = 2, epochs = epochs, base_lr = base_lr, max_lr= max_lr, mode = mode, 
                stepsize = step_size, batch_size = batch_size, use_tensorboard = False):
    start_time = time()   
    global h
    global no_of_epochs
    global name
    date = str(datetime.now().date())
    # logdir in linux:
    logdir = (log_dir + '/' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + '_base-' 
              + str(base_lr) + '_max-' + str(max_lr) + '_' + str(times))
    # logdir in windows:
    ##logdir = (log_dir + '\\' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + 
    #          '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(times))
    name = ('batch size: ' + str(batch_size) + ', mode: ' + str(mode) + ', stepsize: ' 
            + str(stepsize) + ', base-lr: ' + str(base_lr) + ', max-lr ' + str(max_lr) + ', *' + str(times))
    print(' - Model specifics:\t{}'.format(name))
    clr = CyclicLR(base_lr = base_lr, max_lr=max_lr,
                        step_size= stepsize, mode = mode)
    tbCallBack = TensorBoard(log_dir=logdir, histogram_freq=0, 
                         write_graph=False, write_images=False)
    if (use_tensorboard == True):
        Final_model.fit(x = train_images, y = train_labels, epochs = epochs, callbacks= [tbCallBack, clr], 
                            validation_data = (valid_images, valid_labels), batch_size = batch_size, 
                            verbose = verbose)
    else:
        Final_model.fit(x = train_images, y = train_labels, epochs = epochs, callbacks= [clr], 
                            validation_data = (valid_images, valid_labels), batch_size = batch_size, 
                            verbose = verbose)
    no_of_epochs = no_of_epochs + epochs
    h = []
    h = clr.history
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')
print(weights)
print(trainable_layers)
# Out:
# None
# All

# %%
compileModel()
train_Model(times = 5, use_tensorboard = True, verbose = 0)
train_acc = round(Final_model.evaluate(train_images, train_labels, 128)[1],4)
valid_acc = round(Final_model.evaluate(valid_images, valid_labels, 128)[1],4)
test_acc = round(Final_model.evaluate(test_images, test_labels, 128)[1],4)

print("- Training accuracy:\t{}".format(train_acc))
print("- Validation accuracy:\t{}".format(valid_acc))
print("- Test accuracy:\t{}".format(test_acc))

# %matplotlib inline
lr = h['lr'][:step_size]
acc = h['acc'][:step_size]
plt.plot(lr, acc)
# Out:
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.001, *5
# Time usage: 0:03:03 minutes
# 3357/3357 [==============================] - 4s 1ms/step
# 374/374 [==============================] - 1s 2ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracy:	0.5019
# - Validation accuracy:	0.5134
# - Test accuracy:	0.4893

# %%
### choose your learning rates now! The one where the accuracy starts to rise as base_lr and the one where it stops
### growing/ starts to tumble as max_lr
baseLRS = [0.000001, 0.00001, 0.00005]
maxLRS = [0.0001, 0.0002, 0.0003]

# %%
# experiment with different learning rate ranges
def learning_rate_finder(rep = 5, baseLRS = baseLRS, maxLRS = maxLRS):
    start_time = time() 
    global test_acc_list
    global valid_acc_list
    global train_acc_list
    global test_loss_list
    global valid_loss_list
    global train_loss_list
    global test_prec_list
    global valid_prec_list
    global train_prec_list
    global test_rec_list
    global valid_rec_list
    global train_rec_list
    global model_details
    model_details = []
    test_acc_list = []
    valid_acc_list = []
    train_acc_list = []
    test_loss_list = []
    valid_loss_list = []
    train_loss_list = []
    test_prec_list = []
    valid_prec_list = []
    train_prec_list = []
    test_rec_list = []
    valid_rec_list = []
    train_rec_list = []
    for blr in baseLRS:
        print('NEXT LEARNINGRATE: {}'.format(blr))
        for mlr in maxLRS:
            print('Models with base lr = ' + str(blr) + ' and max lr = ' + str(mlr))
            for i in range(rep):
                    compileModel()
                    times = i
                    if (i == 0):
                        train_Model(times = times, epochs = epochs, base_lr = blr, max_lr = mlr, verbose = 0, 
                                    use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = epochs, base_lr = blr, max_lr = mlr, verbose = 0)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_list.append(test_acc)
                    valid_acc_list.append(valid_acc)
                    train_acc_list.append(train_acc)
                    test_loss_list.append(test_loss)
                    valid_loss_list.append(valid_loss)
                    train_loss_list.append(train_loss)
                    test_prec_list.append(test_prec)
                    valid_prec_list.append(valid_prec)
                    train_prec_list.append(train_prec)
                    test_rec_list.append(test_rec)
                    valid_rec_list.append(valid_rec)
                    train_rec_list.append(train_rec)
                    model_details.append(name)
            print("- Training accuracies:\t{}".format([round(el,4) for el in train_acc_list]))
            print("- Validation accuracies:\t{}".format([round(el,4) for el in valid_acc_list]))
            print("- Testing accuracies:\t{}".format([round(el,4) for el in test_acc_list]))
            print('')
            print('')
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# usual training time: 2h
learning_rate_finder()
# %matplotlib inline
acc = h['acc']
plt.plot(acc)
# Out:
# NEXT LEARNINGRATE: 1e-06
# Models with base lr = 1e-06 and max lr = 0.0001
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0001, *0
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 2ms/step
# 934/934 [==============================] - 2s 2ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0001, *1
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0001, *2
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0001, *3
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0001, *4
# Time usage: 0:02:53 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Models with base lr = 1e-06 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *0
# Time usage: 0:02:55 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *1
# Time usage: 0:02:54 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *2
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *3
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0002, *4
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Models with base lr = 1e-06 and max lr = 0.0003
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0003, *0
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0003, *1
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0003, *2
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0003, *3
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-06, max-lr 0.0003, *4
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# NEXT LEARNINGRATE: 1e-05
# Models with base lr = 1e-05 and max lr = 0.0001
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0001, *0
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0001, *1
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0001, *2
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0001, *3
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0001, *4
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Models with base lr = 1e-05 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *0
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *1
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *2
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *3
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0002, *4
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Models with base lr = 1e-05 and max lr = 0.0003
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0003, *0
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0003, *1
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0003, *2
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0003, *3
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 1e-05, max-lr 0.0003, *4
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# NEXT LEARNINGRATE: 5e-05
# Models with base lr = 5e-05 and max lr = 0.0001
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0001, *0
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0001, *1
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0001, *2
# Time usage: 0:02:50 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0001, *3
# Time usage: 0:02:49 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0001, *4
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.4981, 0.4981, 0.5019, 0.4903, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.4866, 0.4866, 0.5134, 0.4706, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.5107, 0.5107, 0.4893, 0.4882, 0.4893]
#
#
# Models with base lr = 5e-05 and max lr = 0.0002
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *0
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *1
# Time usage: 0:02:49 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *2
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *3
# Time usage: 0:02:53 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0002, *4
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.4981, 0.4981, 0.5019, 0.4903, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.4866, 0.4866, 0.5134, 0.4706, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.5107, 0.5107, 0.4893, 0.4882, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Models with base lr = 5e-05 and max lr = 0.0003
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0003, *0
# Time usage: 0:02:52 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0003, *1
# Time usage: 0:02:49 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0003, *2
# Time usage: 0:02:48 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0003, *3
# Time usage: 0:02:51 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0003, *4
# Time usage: 0:02:53 minutes
# 3357/3357 [==============================] - 5s 1ms/step
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# - Training accuracies:	[0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.4981, 0.4981, 0.5019, 0.4903, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019, 0.5019]
# - Validation accuracies:	[0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.4866, 0.4866, 0.5134, 0.4706, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134, 0.5134]
# - Testing accuracies:	[0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.5107, 0.5107, 0.4893, 0.4882, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893, 0.4893]
#
#
# Time usage: 2:13:30 minutes

# %%
titel = model_details[0][:47]
mean_test_acc = []
mean_valid_acc = []
mean_train_acc = []
mean_test_loss = []
mean_valid_loss = []
mean_train_loss = []
mean_test_prec = []
mean_valid_prec = []
mean_train_prec = []
mean_test_rec = []
mean_valid_rec = []
mean_train_rec = []
model_list = []
a = len(test_acc_list)
for i in range(9):
    tals = test_acc_list[i:(i+1)*5]
    vals = valid_acc_list[i:(i+1)*5]
    rals = train_acc_list[i:(i+1)*5]
    tlls = test_loss_list[i:(i+1)*5]
    vlls = valid_loss_list[i:(i+1)*5]
    rlls = train_loss_list[i:(i+1)*5]
    tpls = test_prec_list[i:(i+1)*5]
    vpls = valid_prec_list[i:(i+1)*5]
    rpls = train_prec_list[i:(i+1)*5]
    trls = test_rec_list[i:(i+1)*5]
    vrls = valid_rec_list[i:(i+1)*5]
    rrls = train_rec_list[i:(i+1)*5]
    tmean = round(sum(tals)/len(tals),4)
    vmean = round(sum(vals)/len(vals),4)
    rmean = round(sum(rals)/len(rals),4)
    ltmean = round(sum(tlls)/len(tals),4)
    lvmean = round(sum(vlls)/len(vals),4)
    lrmean = round(sum(rlls)/len(rals),4)
    ptmean = round(sum(tpls)/len(tals),4)
    pvmean = round(sum(vpls)/len(vals),4)
    prmean = round(sum(rpls)/len(rals),4)
    rtmean = round(sum(trls)/len(tals),4)
    rvmean = round(sum(vrls)/len(vals),4)
    rrmean = round(sum(rrls)/len(rals),4)
    mean_test_acc.append(tmean)
    mean_valid_acc.append(vmean)
    mean_train_acc.append(rmean)
    mean_test_loss.append(ltmean)
    mean_valid_loss.append(lvmean)
    mean_train_loss.append(lrmean)
    mean_test_prec.append(ptmean)
    mean_valid_prec.append(pvmean)
    mean_train_prec.append(prmean)
    mean_test_rec.append(rtmean)
    mean_valid_rec.append(rvmean)
    mean_train_rec.append(rrmean)
    model_list.append(model_details[i*5][49:79])
columns = ['test acc', 'valid acc', 'train acc', 'test loss', 'valid loss', 'train loss', 'test prec', \
           'valid prec', 'train prec', 'test rec', 'valid rec', 'train rec']
data = np.array((mean_test_acc, mean_valid_acc, mean_train_acc, mean_test_loss, mean_valid_loss, mean_train_loss,\
                mean_test_prec, mean_valid_prec, mean_train_prec, mean_test_rec, mean_valid_rec, mean_train_rec))
results = pd.DataFrame(data = data, columns = model_list, index = columns)
lr_overview = pd.DataFrame(data = results.transpose(), columns = columns, index = model_list)
#lr_overview
overviewSorted = lr_overview.sort_values(by=['test acc'], ascending = False)
overviewSorted
# Out:
#                                 test acc  valid acc  train acc  test loss  \
# base-lr: 5e-05, max-lr 0.0001,    0.4907     0.5100     0.5013     0.6932
# base-lr: 5e-05, max-lr 0.0002,    0.4906     0.5105     0.5013     0.6932
# base-lr: 5e-05, max-lr 0.0003,    0.4904     0.5108     0.5014     0.6932
# base-lr: 1e-06, max-lr 0.0001,    0.4893     0.5134     0.5019     0.6932
# base-lr: 1e-06, max-lr 0.0002,    0.4893     0.5134     0.5019     0.6932
# base-lr: 1e-06, max-lr 0.0003,    0.4893     0.5134     0.5019     0.6932
# base-lr: 1e-05, max-lr 0.0001,    0.4893     0.5134     0.5019     0.6932
# base-lr: 1e-05, max-lr 0.0002,    0.4893     0.5134     0.5019     0.6932
# base-lr: 1e-05, max-lr 0.0003,    0.4893     0.5134     0.5019     0.6933
#
#                                 valid loss  train loss  test prec  valid prec  \
# base-lr: 5e-05, max-lr 0.0001,      0.6931      0.6931     0.0525      0.0457
# base-lr: 5e-05, max-lr 0.0002,      0.6931      0.6931     0.0461      0.0402
# base-lr: 5e-05, max-lr 0.0003,      0.6931      0.6931     0.0411      0.0358
# base-lr: 1e-06, max-lr 0.0001,      0.6931      0.6931     0.0000      0.0000
# base-lr: 1e-06, max-lr 0.0002,      0.6931      0.6931     0.0000      0.0000
# base-lr: 1e-06, max-lr 0.0003,      0.6930      0.6931     0.0000      0.0000
# base-lr: 1e-05, max-lr 0.0001,      0.6931      0.6931     0.0000      0.0000
# base-lr: 1e-05, max-lr 0.0002,      0.6931      0.6931     0.0000      0.0000
# base-lr: 1e-05, max-lr 0.0003,      0.6930      0.6931     0.0000      0.0000
#
#                                 train prec  test rec  valid rec  train rec
# base-lr: 5e-05, max-lr 0.0001,      0.0503    0.0733     0.0719     0.0732
# base-lr: 5e-05, max-lr 0.0002,      0.0442    0.0644     0.0632     0.0644
# base-lr: 5e-05, max-lr 0.0003,      0.0394    0.0575     0.0564     0.0574
# base-lr: 1e-06, max-lr 0.0001,      0.0000    0.0000     0.0000     0.0000
# base-lr: 1e-06, max-lr 0.0002,      0.0000    0.0000     0.0000     0.0000
# base-lr: 1e-06, max-lr 0.0003,      0.0000    0.0000     0.0000     0.0000
# base-lr: 1e-05, max-lr 0.0001,      0.0000    0.0000     0.0000     0.0000
# base-lr: 1e-05, max-lr 0.0002,      0.0000    0.0000     0.0000     0.0000
# base-lr: 1e-05, max-lr 0.0003,      0.0000    0.0000     0.0000     0.0000

# %%
blr = 0.00005
mlr = 0.0001

# %%
os.chdir(code_dir + '/Excel')
savename = ('AfterTuningLR_modelOverview_Xception_bs-' + str(batch_size) + '_' + str(mode) + '_sz-' 
            + str(step_size) + '_' + str(weights) + '_' + str(trainable_layers) + '_' + str(epochs) + 'epochs')
savename
# Out:
# 'AfterTuningLR_modelOverview_Xception_bs-64_triangular_sz-420_None_All_48epochs'

# %%
overviewSorted.to_csv(savename)

# %%
import seaborn as sns
sns.set()
heatmap = sns.heatmap(results.iloc[:3,:].transpose(), annot=True, fmt = 'f')

# %%
# %matplotlib inline

f, (ax1, ax2) = plt.subplots(2, 1, sharex='col', sharey='row')
ax1.plot(mean_test_acc, color = 'r')
ax1.axis([0, 8, 0.5, 1])
ax1.set_title('Close up')
ax1.plot(mean_valid_acc)
ax1.plot(mean_train_acc, color = 'g')
ax2.set_title('Zoom')
ax2.plot(mean_test_acc, color = 'r')
ax2.axis([0, 8, 0.7, 0.8])
ax2.plot(mean_valid_acc)
ax2.plot(mean_train_acc, color = 'g')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
stepsizes128 = [157, 210, 262]
stepsizes64 = [315, 420,525]
batch_sizes = [64, 128]
modes = ['triangular', 'triangular2']
rep = 1

# %%
def hp_tuner(base_lr = blr, max_lr = mlr, rep = 5):
    start_time = time()  
    global test_acc_l
    global valid_acc_l
    global train_acc_l
    global test_loss_l
    global valid_loss_l
    global train_loss_l
    global test_prec_l
    global valid_prec_l
    global train_prec_l
    global test_rec_l
    global valid_rec_l
    global train_rec_l
    global model_det
    model_det = []
    test_acc_l = []
    valid_acc_l = []
    train_acc_l = []
    test_loss_l = []
    valid_loss_l = []
    train_loss_l = []
    test_prec_l = []
    valid_prec_l = []
    train_prec_l = []
    test_rec_l = []
    valid_rec_l = []
    train_rec_l = []
    for bs in batch_sizes:
        if (bs == 64):
            stepsizes = stepsizes64
        if (bs ==128):
            stepsizes = stepsizes128
        for sz in stepsizes: 
            for md in modes:
                i = 0
                mid_time = time()
                while (i < rep):
                    compileModel()
                    times = i
                    if (i == 0):
                        train_Model(times = times, epochs = 48, base_lr = base_lr, max_lr = max_lr, verbose = 0,
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = 48, base_lr = base_lr, max_lr = max_lr, verbose = 0, 
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = False)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_l.append(test_acc)
                    valid_acc_l.append(valid_acc)
                    train_acc_l.append(train_acc)
                    test_loss_l.append(test_loss)
                    valid_loss_l.append(valid_loss)
                    train_loss_l.append(train_loss)
                    test_prec_l.append(test_prec)
                    valid_prec_l.append(valid_prec)
                    train_prec_l.append(train_prec)
                    test_rec_l.append(test_rec)
                    valid_rec_l.append(valid_rec)
                    train_rec_l.append(train_rec)
                    model_det.append(name)
    ### training the same model for more epochs
                    if (i == 0):
                        train_Model(times = times, epochs = 48, base_lr = base_lr, max_lr = max_lr, verbose = 0,
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = True)
                    else:
                        train_Model(times = times, epochs = 48, base_lr = base_lr, max_lr = max_lr, verbose = 0, 
                                    batch_size = bs, stepsize = sz, mode = md, use_tensorboard = False)
                    valid_metrics = Final_model.evaluate(valid_images, valid_labels)
                    test_metrics = Final_model.evaluate(test_images, test_labels)
                    train_metrics = Final_model.evaluate(train_images, train_labels)
                    
                    train_acc = train_metrics[1]
                    valid_acc = valid_metrics[1]
                    test_acc = test_metrics[1]
                    train_loss = train_metrics[0]
                    valid_loss = valid_metrics[0]
                    test_loss = test_metrics[0]
                    train_prec = train_metrics[2]
                    valid_prec = valid_metrics[2]
                    test_prec = test_metrics[2]
                    train_rec = train_metrics[3]
                    valid_rec = valid_metrics[3]
                    test_rec = test_metrics[3]                                
                    test_acc_l.append(test_acc)
                    valid_acc_l.append(valid_acc)
                    train_acc_l.append(train_acc)
                    test_loss_l.append(test_loss)
                    valid_loss_l.append(valid_loss)
                    train_loss_l.append(train_loss)
                    test_prec_l.append(test_prec)
                    valid_prec_l.append(valid_prec)
                    train_prec_l.append(train_prec)
                    test_rec_l.append(test_rec)
                    valid_rec_l.append(valid_rec)
                    train_rec_l.append(train_rec)
                    name2 = name + '_x2'
                    model_det.append(name2)
                    print(log_dir)
                    i += 1
                mid_end_time = time()
                mid_time_dif = mid_end_time - mid_time
                print('Time usage: ' + str(timedelta(seconds=int(round(mid_time_dif)))) + ' minutes')
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# usual training time: 4:51 - 5:46
rep = 5
hp_tuner(rep = rep)
# Out:
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:55 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:50 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:55 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:30:00 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:54 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:50 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.114682). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:50 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.108057). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 315, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:30:03 minutes
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.107751). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.103569). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:55 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:30:08 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.107022). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:58 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.103817). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.100973). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.113810). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:50 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 420, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:30:07 minutes
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:57 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:56 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:50 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:53 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:29:56 minutes
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.101383). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:55 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.148660). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:55 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.140310). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:59 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.135556). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:03:00 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.130352). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:58 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 64, mode: triangular2, stepsize: 525, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:52 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:30:09 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111886). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.110587). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.110842). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.115024). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.113182). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:43 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:27 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.130922). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:43 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.125878). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:44 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.122039). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.118354). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:42 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.119465). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 157, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:35 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.118378). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:33 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.118926). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.120063). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:45 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.120205). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.124110). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:42 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:07 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.122590). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.122992). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.120756). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:46 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:43 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.125838). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:43 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.197306). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 210, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:42 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:30 minutes
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.138903). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:51 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:43 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.138387). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:42 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.140226). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.137598). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.141285). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:33 minutes
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.181868). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *0
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.177009). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *1
# Time usage: 0:02:42 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.169798). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:49 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *2
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.163838). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:47 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *3
# Time usage: 0:02:40 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.159226). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:02:48 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
#  - Model specifics:	batch size: 128, mode: triangular2, stepsize: 262, base-lr: 5e-05, max-lr 0.0006, *4
# Time usage: 0:02:41 minutes
# 374/374 [==============================] - 1s 1ms/step
# 934/934 [==============================] - 1s 1ms/step
# 3357/3357 [==============================] - 5s 1ms/step
# /home/rick/Documents/HannahZ/Code/logs
# Time usage: 0:28:33 minutes
# Time usage: 5:51:10 minutes

# %%
rep = 5
titel = model_det[0][:47]
mean_test_a = []
mean_valid_a = []
mean_train_a = []
mean_test_l = []
mean_valid_l = []
mean_train_l = []
mean_test_p = []
mean_valid_p = []
mean_train_p = []
mean_test_r = []
mean_valid_r = []
mean_train_r = []
model_l = []
a = int(len(test_acc_l)/rep)
for i in range(a):
    tals = test_acc_l[i:(i+1)*rep]
    vals = valid_acc_l[i:(i+1)*rep]
    rals = train_acc_l[i:(i+1)*rep]
    tlls = test_loss_l[i:(i+1)*rep]
    vlls = valid_loss_l[i:(i+1)*rep]
    rlls = train_loss_l[i:(i+1)*rep]
    tpls = test_prec_l[i:(i+1)*rep]
    vpls = valid_prec_l[i:(i+1)*rep]
    rpls = train_prec_l[i:(i+1)*rep]
    trls = test_rec_l[i:(i+1)*rep]
    vrls = valid_rec_l[i:(i+1)*rep]
    rrls = train_rec_l[i:(i+1)*rep]
    tmean = round(sum(tals)/len(tals),4)
    vmean = round(sum(vals)/len(vals),4)
    rmean = round(sum(rals)/len(rals),4)
    ltmean = round(sum(tlls)/len(tals),4)
    lvmean = round(sum(vlls)/len(vals),4)
    lrmean = round(sum(rlls)/len(rals),4)
    ptmean = round(sum(tpls)/len(tals),4)
    pvmean = round(sum(vpls)/len(vals),4)
    prmean = round(sum(rpls)/len(rals),4)
    rtmean = round(sum(trls)/len(tals),4)
    rvmean = round(sum(vrls)/len(vals),4)
    rrmean = round(sum(rrls)/len(rals),4)
    mean_test_a.append(tmean)
    mean_valid_a.append(vmean)
    mean_train_a.append(rmean)
    mean_test_l.append(ltmean)
    mean_valid_l.append(lvmean)
    mean_train_l.append(lrmean)
    mean_test_p.append(ptmean)
    mean_valid_p.append(pvmean)
    mean_train_p.append(prmean)
    mean_test_r.append(rtmean)
    mean_valid_r.append(rvmean)
    mean_train_r.append(rrmean)
    if (model_det[i*rep][-2:] == 'x2'):
        model_l.append(model_det[i*rep][6:49] + ' ' + model_det[i*rep][-2:])
    else:
        model_l.append(model_det[i*rep][6:49])

# %%
print(model_det[8][6:49])
print(model_det[0][-2:])
# Out:
# size: 64, mode: triangular, stepsize: 315,
# *0

# %%
savename2 = ('AfterTuningHP_modelOverview_Xception_bs-' + str(batch_size) + '_' + str(mode) + '_sz-' 
             + str(step_size) + '_' + str(weights) + '_' + str(trainable_layers) + '_' + str(epochs) + 'epochs')
savename2
# Out:
# 'AfterTuningHP_modelOverview_Xception_bs-64_triangular_sz-420_imagenet_86_48epochs'

# %%
cols = ['test acc', 'valid acc', 'train acc', 'test loss', 'valid loss', 'train loss', 'test prec', \
           'valid prec', 'train prec', 'test rec', 'valid rec', 'train rec']
data2 = np.array((mean_test_a, mean_valid_a, mean_train_a, mean_test_l, mean_valid_l, mean_train_l,\
                mean_test_p, mean_valid_p, mean_train_p, mean_test_r, mean_valid_r, mean_train_r))
results2 = pd.DataFrame(data = data2, columns = model_l, index = cols)
hp_overview = pd.DataFrame(data = results2.transpose(), columns = cols, index = model_l)
hpOverviewSorted = hp_overview.sort_values(by=['test acc'], ascending = False)
hpOverviewSorted
os.chdir(code_dir + '/Excel')
hpOverviewSorted.to_csv(savename)
# Out:
#                                                 test acc  valid acc  \
# size: 64, mode: triangular, stepsize: 315,        0.7398     0.6995
# size: 64, mode: triangular2, stepsize: 420, x2    0.7325     0.6898
# size: 64, mode: triangular, stepsize: 420,  x2    0.7321     0.6882
# size: 64, mode: triangular, stepsize: 315,  x2    0.7319     0.6937
# size: 64, mode: triangular, stepsize: 420,        0.7319     0.6895
# size: 64, mode: triangular2, stepsize: 315, x2    0.7316     0.6884
# size: 64, mode: triangular2, stepsize: 525, x2    0.7314     0.6889
# size: 64, mode: triangular2, stepsize: 420,       0.7311     0.6882
# size: 64, mode: triangular2, stepsize: 315,       0.7310     0.6884
# size: 64, mode: triangular2, stepsize: 525,       0.7308     0.6889
# size: 64, mode: triangular, stepsize: 525,        0.7305     0.6886
# size: 64, mode: triangular, stepsize: 525,  x2    0.7293     0.6877
# size: 128, mode: triangular, stepsize: 157,       0.7292     0.6869
# size: 128, mode: triangular, stepsize: 210, x2    0.7291     0.6858
# size: 128, mode: triangular2, stepsize: 210 x2    0.7287     0.6854
# size: 128, mode: triangular2, stepsize: 210       0.7286     0.6854
# size: 128, mode: triangular2, stepsize: 157 x2    0.7284     0.6851
# size: 128, mode: triangular2, stepsize: 157       0.7282     0.6854
# size: 128, mode: triangular, stepsize: 210,       0.7281     0.6846
# size: 128, mode: triangular, stepsize: 157, x2    0.7278     0.6853
# size: 128, mode: triangular2, stepsize: 262 x2    0.7278     0.6841
# size: 128, mode: triangular, stepsize: 262, x2    0.7271     0.6840
# size: 128, mode: triangular, stepsize: 262,       0.7270     0.6840
# size: 128, mode: triangular2, stepsize: 262       0.7263     0.6830
#
#                                                 train acc  test loss  \
# size: 64, mode: triangular, stepsize: 315,         0.7440     2.3820
# size: 64, mode: triangular2, stepsize: 420, x2     0.7363     2.3647
# size: 64, mode: triangular, stepsize: 420,  x2     0.7355     2.4106
# size: 64, mode: triangular, stepsize: 315,  x2     0.7374     2.5285
# size: 64, mode: triangular, stepsize: 420,         0.7363     2.3584
# size: 64, mode: triangular2, stepsize: 315, x2     0.7357     2.3551
# size: 64, mode: triangular2, stepsize: 525, x2     0.7349     2.3836
# size: 64, mode: triangular2, stepsize: 420,        0.7345     2.3902
# size: 64, mode: triangular2, stepsize: 315,        0.7363     2.3715
# size: 64, mode: triangular2, stepsize: 525,        0.7342     2.3876
# size: 64, mode: triangular, stepsize: 525,         0.7342     2.3888
# size: 64, mode: triangular, stepsize: 525,  x2     0.7333     2.4195
# size: 128, mode: triangular, stepsize: 157,        0.7322     2.4303
# size: 128, mode: triangular, stepsize: 210, x2     0.7314     2.4583
# size: 128, mode: triangular2, stepsize: 210 x2     0.7304     2.4645
# size: 128, mode: triangular2, stepsize: 210        0.7308     2.4571
# size: 128, mode: triangular2, stepsize: 157 x2     0.7310     2.4433
# size: 128, mode: triangular2, stepsize: 157        0.7309     2.4483
# size: 128, mode: triangular, stepsize: 210,        0.7304     2.4558
# size: 128, mode: triangular, stepsize: 157, x2     0.7306     2.4714
# size: 128, mode: triangular2, stepsize: 262 x2     0.7296     2.4592
# size: 128, mode: triangular, stepsize: 262, x2     0.7288     2.4832
# size: 128, mode: triangular, stepsize: 262,        0.7288     2.4875
# size: 128, mode: triangular2, stepsize: 262        0.7277     2.4864
#
#                                                 valid loss  train loss  \
# size: 64, mode: triangular, stepsize: 315,          2.5576      2.1259
# size: 64, mode: triangular2, stepsize: 420, x2      2.5506      2.1143
# size: 64, mode: triangular, stepsize: 420,  x2      2.5952      2.1579
# size: 64, mode: triangular, stepsize: 315,  x2      2.6845      2.2429
# size: 64, mode: triangular, stepsize: 420,          2.5379      2.1026
# size: 64, mode: triangular2, stepsize: 315, x2      2.5174      2.0972
# size: 64, mode: triangular2, stepsize: 525, x2      2.5752      2.1420
# size: 64, mode: triangular2, stepsize: 420,         2.5738      2.1364
# size: 64, mode: triangular2, stepsize: 315,         2.5425      2.1148
# size: 64, mode: triangular2, stepsize: 525,         2.5787      2.1486
# size: 64, mode: triangular, stepsize: 525,          2.5773      2.1402
# size: 64, mode: triangular, stepsize: 525,  x2      2.6146      2.1786
# size: 128, mode: triangular, stepsize: 157,         2.6365      2.1907
# size: 128, mode: triangular, stepsize: 210, x2      2.7150      2.2340
# size: 128, mode: triangular2, stepsize: 210 x2      2.7303      2.2418
# size: 128, mode: triangular2, stepsize: 210         2.7195      2.2347
# size: 128, mode: triangular2, stepsize: 157 x2      2.6830      2.2151
# size: 128, mode: triangular2, stepsize: 157         2.6797      2.2173
# size: 128, mode: triangular, stepsize: 210,         2.7038      2.2294
# size: 128, mode: triangular, stepsize: 157, x2      2.6930      2.2353
# size: 128, mode: triangular2, stepsize: 262 x2      2.7427      2.2459
# size: 128, mode: triangular, stepsize: 262, x2      2.7614      2.2671
# size: 128, mode: triangular, stepsize: 262,         2.7592      2.2666
# size: 128, mode: triangular2, stepsize: 262         2.7658      2.2709
#
#                                                 test prec  valid prec  \
# size: 64, mode: triangular, stepsize: 315,         0.6718      0.6223
# size: 64, mode: triangular2, stepsize: 420, x2     0.6647      0.6152
# size: 64, mode: triangular, stepsize: 420,  x2     0.6643      0.6134
# size: 64, mode: triangular, stepsize: 315,  x2     0.6644      0.6168
# size: 64, mode: triangular, stepsize: 420,         0.6641      0.6145
# size: 64, mode: triangular2, stepsize: 315, x2     0.6638      0.6132
# size: 64, mode: triangular2, stepsize: 525, x2     0.6654      0.6161
# size: 64, mode: triangular2, stepsize: 420,        0.6632      0.6131
# size: 64, mode: triangular2, stepsize: 315,        0.6632      0.6125
# size: 64, mode: triangular2, stepsize: 525,        0.6649      0.6162
# size: 64, mode: triangular, stepsize: 525,         0.6631      0.6144
# size: 64, mode: triangular, stepsize: 525,  x2     0.6636      0.6154
# size: 128, mode: triangular, stepsize: 157,        0.6632      0.6140
# size: 128, mode: triangular, stepsize: 210, x2     0.6628      0.6129
# size: 128, mode: triangular2, stepsize: 210 x2     0.6622      0.6122
# size: 128, mode: triangular2, stepsize: 210        0.6623      0.6123
# size: 128, mode: triangular2, stepsize: 157 x2     0.6623      0.6123
# size: 128, mode: triangular2, stepsize: 157        0.6621      0.6125
# size: 128, mode: triangular, stepsize: 210,        0.6619      0.6118
# size: 128, mode: triangular, stepsize: 157, x2     0.6618      0.6126
# size: 128, mode: triangular2, stepsize: 262 x2     0.6622      0.6118
# size: 128, mode: triangular, stepsize: 262, x2     0.6613      0.6115
# size: 128, mode: triangular, stepsize: 262,        0.6610      0.6110
# size: 128, mode: triangular2, stepsize: 262        0.6605      0.6106
#
#                                                 train prec  test rec  \
# size: 64, mode: triangular, stepsize: 315,          0.6713    0.9656
# size: 64, mode: triangular2, stepsize: 420, x2      0.6633    0.9679
# size: 64, mode: triangular, stepsize: 420,  x2      0.6624    0.9675
# size: 64, mode: triangular, stepsize: 315,  x2      0.6645    0.9649
# size: 64, mode: triangular, stepsize: 420,          0.6632    0.9674
# size: 64, mode: triangular2, stepsize: 315, x2      0.6624    0.9675
# size: 64, mode: triangular2, stepsize: 525, x2      0.6640    0.9654
# size: 64, mode: triangular2, stepsize: 420,         0.6613    0.9688
# size: 64, mode: triangular2, stepsize: 315,         0.6630    0.9673
# size: 64, mode: triangular2, stepsize: 525,         0.6633    0.9660
# size: 64, mode: triangular, stepsize: 525,          0.6617    0.9685
# size: 64, mode: triangular, stepsize: 525,  x2      0.6625    0.9662
# size: 128, mode: triangular, stepsize: 157,         0.6611    0.9668
# size: 128, mode: triangular, stepsize: 210, x2      0.6600    0.9679
# size: 128, mode: triangular2, stepsize: 210 x2      0.6588    0.9687
# size: 128, mode: triangular2, stepsize: 210         0.6593    0.9683
# size: 128, mode: triangular2, stepsize: 157 x2      0.6597    0.9680
# size: 128, mode: triangular2, stepsize: 157         0.6598    0.9678
# size: 128, mode: triangular, stepsize: 210,         0.6590    0.9683
# size: 128, mode: triangular, stepsize: 157, x2      0.6596    0.9674
# size: 128, mode: triangular2, stepsize: 262 x2      0.6588    0.9682
# size: 128, mode: triangular, stepsize: 262, x2      0.6578    0.9690
# size: 128, mode: triangular, stepsize: 262,         0.6574    0.9692
# size: 128, mode: triangular2, stepsize: 262         0.6567    0.9693
#
#                                                 valid rec  train rec
# size: 64, mode: triangular, stepsize: 315,         0.8951     0.9507
# size: 64, mode: triangular2, stepsize: 420, x2     0.9017     0.9544
# size: 64, mode: triangular, stepsize: 420,  x2     0.9020     0.9544
# size: 64, mode: triangular, stepsize: 315,  x2     0.8966     0.9517
# size: 64, mode: triangular, stepsize: 420,         0.9013     0.9542
# size: 64, mode: triangular2, stepsize: 315, x2     0.9041     0.9548
# size: 64, mode: triangular2, stepsize: 525, x2     0.9008     0.9521
# size: 64, mode: triangular2, stepsize: 420,        0.9064     0.9558
# size: 64, mode: triangular2, stepsize: 315,        0.9023     0.9546
# size: 64, mode: triangular2, stepsize: 525,        0.9029     0.9527
# size: 64, mode: triangular, stepsize: 525,         0.9042     0.9552
# size: 64, mode: triangular, stepsize: 525,  x2     0.9030     0.9532
# size: 128, mode: triangular, stepsize: 157,        0.9033     0.9538
# size: 128, mode: triangular, stepsize: 210, x2     0.9036     0.9553
# size: 128, mode: triangular2, stepsize: 210 x2     0.9055     0.9561
# size: 128, mode: triangular2, stepsize: 210        0.9045     0.9557
# size: 128, mode: triangular2, stepsize: 157 x2     0.9039     0.9551
# size: 128, mode: triangular2, stepsize: 157        0.9041     0.9548
# size: 128, mode: triangular, stepsize: 210,        0.9045     0.9556
# size: 128, mode: triangular, stepsize: 157, x2     0.9040     0.9545
# size: 128, mode: triangular2, stepsize: 262 x2     0.9047     0.9557
# size: 128, mode: triangular, stepsize: 262, x2     0.9067     0.9564
# size: 128, mode: triangular, stepsize: 262,        0.9071     0.9568
# size: 128, mode: triangular2, stepsize: 262        0.9071     0.9568

# %%
# %matplotlib inline
plt.figure(figsize=(6, 8))

sns.heatmap(hp_overview.iloc[:,:3], annot=True,  fmt = 'f')

# %%
# %matplotlib inline

f, (ax1, ax2) = plt.subplots(2, 1, sharex='col', sharey='row')
ax1.plot(mean_test_a, color = 'r')
ax1.axis([0, 9, 0.5, 1])
ax1.set_title('Close up')
ax1.plot(mean_valid_a)
ax1.plot(mean_train_a, color = 'g')
ax2.set_title('Zoom')
ax2.plot(mean_test_a, color = 'r')
ax2.axis([0, 9, 0.73, 0.79])
ax2.plot(mean_valid_a)
ax2.plot(mean_train_a, color = 'g')
# Out:
# [0, 9, 0.5, 1]
# Text(0.5,1,'Close up')
# Text(0.5,1,'Zoom')
# [0, 9, 0.73, 0.79]

# %%
hp_overview.sort_values(by=['test acc'], ascending = False).iloc[:3,:]
# hp_overview.sort_values(by=['test loss'], ascending = True).iloc[:3,:]
# hp_overview.sort_values(by=['test prec'], ascending = False).iloc[:3,:]
# hp_overview.sort_values(by=['test rec'], ascending = False).iloc[:3,:]
model_det[0][49:79]
# Out:
#                                                 test acc  valid acc  \
# size: 64, mode: triangular, stepsize: 315,        0.7398     0.6995
# size: 64, mode: triangular2, stepsize: 420, x2    0.7325     0.6898
# size: 64, mode: triangular, stepsize: 420,  x2    0.7321     0.6882
#
#                                                 train acc  test loss  \
# size: 64, mode: triangular, stepsize: 315,         0.7440     2.3820
# size: 64, mode: triangular2, stepsize: 420, x2     0.7363     2.3647
# size: 64, mode: triangular, stepsize: 420,  x2     0.7355     2.4106
#
#                                                 valid loss  train loss  \
# size: 64, mode: triangular, stepsize: 315,          2.5576      2.1259
# size: 64, mode: triangular2, stepsize: 420, x2      2.5506      2.1143
# size: 64, mode: triangular, stepsize: 420,  x2      2.5952      2.1579
#
#                                                 test prec  valid prec  \
# size: 64, mode: triangular, stepsize: 315,         0.6718      0.6223
# size: 64, mode: triangular2, stepsize: 420, x2     0.6647      0.6152
# size: 64, mode: triangular, stepsize: 420,  x2     0.6643      0.6134
#
#                                                 train prec  test rec  \
# size: 64, mode: triangular, stepsize: 315,          0.6713    0.9656
# size: 64, mode: triangular2, stepsize: 420, x2      0.6633    0.9679
# size: 64, mode: triangular, stepsize: 420,  x2      0.6624    0.9675
#
#                                                 valid rec  train rec
# size: 64, mode: triangular, stepsize: 315,         0.8951     0.9507
# size: 64, mode: triangular2, stepsize: 420, x2     0.9017     0.9544
# size: 64, mode: triangular, stepsize: 420,  x2     0.9020     0.9544
# 'base-lr: 5e-05, max-lr 0.0006,'

# %%
# decide on best hyperparameters
batch_size = 64
step_size = 315
mode = 'triangular'
base_lr = 0.00005
max_lr = 0.0006
epochs = 48
d3 = {}
name = ('bs-' + str(batch_size) + '_' + str(mode) + '_sz-' + str(step_size) + '_blr-' + str(base_lr) + '_mlr-' 
        + str(max_lr)) + '_' + str(weights) + '_' + str(trainable_layers)
model_dir + '/' + name + '.hdf5'
# Out:
# '/home/rick/Documents/HannahZ/Code/Final_models/bs-64_triangular_sz-315_blr-5e-05_mlr-0.0006_imagenet_86.hdf5'

# %%
def trainModels(batch_size = batch_size, stepsize = step_size, mode = mode, max_lr = max_lr, base_lr = base_lr, 
                epochs = epochs, verbose = 0):
    start_time = time()   
    global name
    global filepath
    global d    
    date = str(datetime.now().date())
    d = {}
    for i in range(5):
        compileModel()
        # logdir in linux:
        logdir = (log_dir + '/' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) 
                  + '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(i))
        # logdir in windows:
        ##logdir = (log_dir + '\\' + date + '_' + str(batch_size) + '_' + str(mode) + '_si-' + str(stepsize) + 
        #          '_base-' + str(base_lr) + '_max-' + str(max_lr) + '_' + str(i))
        name = ('batch size: ' + str(batch_size) + ', mode: ' + str(mode) + ', stepsize: ' 
                + str(stepsize) + ', base-lr: ' + str(base_lr) + ', max-lr ' + str(max_lr) + '_' + str(i))
        print(' - Model specifics:\t{}'.format(name))
        clr = CyclicLR(base_lr = base_lr, max_lr=max_lr, step_size= stepsize, mode = mode)
        fp = ('bs-' + str(batch_size) + '_' + str(mode) + '_sz-' + str(step_size) + '_blr-' + str(base_lr) 
              + '_mlr-' + str(max_lr) + '_' + weights + '_' + str(trainable_layers) + '_' + str(i))
        filepath = weight_dir + '/' + fp + '.hdf5'
        checkp = ModelCheckpoint(filepath, monitor='val_acc', verbose= verbose, save_weights_only=True, 
                                save_best_only=True, mode='max', period=1)
        tbCallBack = TensorBoard(log_dir=logdir, histogram_freq=0, 
                             write_graph=False, write_images=False)
        d["FinalModel{0}".format(i)]= Final_model
        d["FinalModel{0}".format(i)].fit(x = train_images, y = train_labels, epochs = epochs, 
                                         callbacks= [tbCallBack, clr, checkp], batch_size = batch_size,
                                         validation_data = (valid_images, valid_labels), verbose = 0)
    end_time = time()
    time_dif = end_time - start_time
    print('Time usage: ' + str(timedelta(seconds=int(round(time_dif)))) + ' minutes')

# %%
# build best model again
# usual time: 15 minutes
fm = ['FinalModel1', 'FinalModel2', 'FinalModel3', 'FinalModel4', 'FinalModel5']
metrics = ['loss', 'acc', 'precision', 'recall']

name = ('bs-' + str(batch_size) + '_' + str(mode) + '_sz-' + str(step_size) + '_blr-' + str(base_lr) + '_mlr-' 
       + str(max_lr)) + '_' + str(weights) + '_' + str(trainable_layers)

trainModels(base_lr = base_lr, max_lr= max_lr, epochs = epochs, verbose = 0,
           batch_size = batch_size, stepsize = step_size, mode = mode)
# Out:
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006_0
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.146444). Check your callbacks.
#   % delta_t_median)
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006_1
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.154987). Check your callbacks.
#   % delta_t_median)
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006_2
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.146041). Check your callbacks.
#   % delta_t_median)
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006_3
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.152576). Check your callbacks.
#   % delta_t_median)
#  - Model specifics:	batch size: 64, mode: triangular, stepsize: 315, base-lr: 5e-05, max-lr 0.0006_4
# /home/rick/.conda/envs/hannah_z/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.148120). Check your callbacks.
#   % delta_t_median)
# Time usage: 0:15:45 minutes

# %%
# find out where 'bs' starts and '_' ends...
i = 0
filename = str(filepath)[42:99] + str(i) + str(filepath)[100:]
print(filename)
# Out:
# bs-64_triangular_sz-315_blr-5e-05_mlr-0.0006_imagenet_86_0.hdf5

# %%
# usual time: 2 minutes
startTime = time()
FinalModelList = {}
for i in range(5):
    filename = str(filepath)[42:99] + str(i) + str(filepath)[100:]
    print(filename)
    os.chdir(weight_dir)
    compileModel()
    Final_model.load_weights(filename)
    FinalModelList["FinalModel{0}".format(i)]= Final_model
    test_m = Final_model.evaluate(test_images, test_labels, verbose = 0)
    test_m = [round(el, 4) for el in test_m]
    valid_m = Final_model.evaluate(valid_images, valid_labels, verbose = 0)
    valid_m = [round(el, 4) for el in valid_m]
    train_m = Final_model.evaluate(train_images, train_labels, verbose = 0)
    train_m = [round(el, 4) for el in train_m]
    col = ["FinalModel{0}".format(i)]
    d3["td{0}".format(i)]= pd.DataFrame(data = test_m[:4], columns = col, index = metrics)
#     print('Best test accuracy model {}: {}'.format(i, test_m[1]))
#     print('Best validation accuracy model {}: {}'.format(i, valid_m[1]))
#     print('Best training accuracy model {}: {}'.format(i, train_m[1]))
    print('')
endTime = time()
finalTime = endTime - startTime
print('Time usage: ' + str(timedelta(seconds=int(round(finalTime)))) + ' minutes')
# Out:
# bs-64_triangular_sz-315_blr-5e-05_mlr-0.0006_imagenet_86_0.hdf5
#
# bs-64_triangular_sz-315_blr-5e-05_mlr-0.0006_imagenet_86_1.hdf5
#
# bs-64_triangular_sz-315_blr-5e-05_mlr-0.0006_imagenet_86_2.hdf5

# %%
FinalResults = pd.concat([d3['td0'], d3['td1'], d3['td2'], d3['td3'], d3['td4']], axis=1)
FinalResults = pd.DataFrame(data = FinalResults.transpose(), columns = metrics)
FinalResults.sort_values(by = ['acc'], ascending = False)
# Out:
#                loss     acc  precision  recall
# FinalModel3  0.7144  0.8223     0.7889  0.8951
# FinalModel2  0.7447  0.7998     0.7503  0.9245
# FinalModel0  1.0652  0.7666     0.6989  0.9640
# FinalModel4  1.4070  0.7527     0.6847  0.9671
# FinalModel1  1.5687  0.7323     0.6630  0.9769

# %%
models = [FinalModelList['FinalModel0'], FinalModelList['FinalModel1'], FinalModelList['FinalModel2'], \
          FinalModelList['FinalModel3'], FinalModelList['FinalModel4']]
def ensemble(models):    
    global eModel
    outputs = [model.outputs[0] for model in models]
    y = keras.layers.Average()(outputs)   
    eModel = Model(inputs=Model_base.input, outputs = y, name='ensemble')  
    eModel.compile(optimizer='rmsprop', loss='binary_crossentropy',
                   metrics=['accuracy', precision, recall, fmeasure])
    return eModel
ensemble_model = ensemble(models)
ensResults = ensemble_model.evaluate(test_images, test_labels)
Res = pd.DataFrame(data = ensResults[:4], columns = ['ensembleModel'], index = metrics)
Res.transpose()
FinalResults = pd.concat([d3['td0'], d3['td1'], d3['td2'], d3['td3'], d3['td4'], Res], axis=1)
FinalResults = pd.DataFrame(data = FinalResults.transpose(), columns = metrics)
FinalResults.sort_values(by = ['acc'], ascending = False)
# Out:
# 934/934 [==============================] - 6s 6ms/step
#                    loss       acc  precision    recall
# ensembleModel  0.757702  0.775161   0.708886  0.958151
#                    loss       acc  precision    recall
# FinalModel3    0.714400  0.822300   0.788900  0.895100
# FinalModel2    0.744700  0.799800   0.750300  0.924500
# ensembleModel  0.757702  0.775161   0.708886  0.958151
# FinalModel0    1.065200  0.766600   0.698900  0.964000
# FinalModel4    1.407000  0.752700   0.684700  0.967100
# FinalModel1    1.568700  0.732300   0.663000  0.976900

# %%
# change again the path name
# saving the model   
i = 3
FinName = 'Xception_' + str(filepath)[42:101] + str(i) 
print(FinName)
os.chdir(model_dir)
# Final_model1 = ensemble_model # or
Final_model = FinalModelList['FinalModel{0}'.format(i)]
# predictions = np.round(Final_model.predict(test_images),4)           
# predictions_ensemble = np.round(Final_model1.predict(test_images),4)
# for v1, v2 in zip(predictions[:5], predictions_ensemble[:5]):
#     print('Best model prediction and ensemble prediction: \t{} \t{}'.format(v1, v2))
# Out:
# Xception_bs-64_triangular2_sz-525_blr-1e-06_mlr-0.0004_imagenet_All_3

# %%
Final_model.save(FinName)

# %%
# calculating the ROC    
y_pred = Final_model.predict(test_images, batch_size = 64)
y_true = test_labels
fpr, tpr, thresholds = roc_curve(y_true, y_pred, pos_label = 1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='lime',
         lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='darkgrey', lw=2, linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# calculating the ROC    
y_pred = Final_model.predict(test_images, batch_size = 64)
y_true = test_labels
fpr, tpr, thresholds = roc_curve(y_true, y_pred, pos_label = 1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='lime',
         lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='darkgrey', lw=2, linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Curve')
plt.legend(loc="lower right")
plt.show()

# evaluation with bootstrapping
seed(1)
ratio = 0.1
y_pred_1 = Final_model.predict(test_images, batch_size = 64).squeeze(axis = 1)
def subsample(dataset = y_pred_1, labels = test_labels, ratio= ratio):
    pred_sample = list()
    label_sample = list()
    n_sample = round(len(dataset) * ratio)
    index = sample(range(len(dataset)), n_sample)
    pred_sample = dataset[index]
    label_sample = labels[index]           
    return pred_sample, label_sample

loss = []
accuracy = []
precisions = []
recalls = []
f_measures = []
    
def bootstrap(iterations = 20, ratio = ratio, dataset = y_pred_1, labels = test_labels):    
    for i in range (iterations):
        b_pred, b_labels = subsample(dataset, labels, ratio)
        lo = cross_entropy(b_pred, b_labels)
        b_pred_rounded = b_pred.round()
        acc = accuracy_score(b_labels, b_pred_rounded)
        pre = precision_score(b_labels, b_pred_rounded)
        rec = recall_score(b_labels, b_pred_rounded)
        fme = f1_score(b_labels, b_pred_rounded)
        loss.append(lo)
        accuracy.append(acc)
        precisions.append(pre)
        recalls.append(rec)
        f_measures.append(fme)
        if (i%100 == 0): 
            print('Iteration_' + str(i))
        
bootstrap(iterations = 10000)
plt.hist(accuracy, bins = 100, range = [0,1])
plt.hist(precisions, bins = 100, range = [0,1])
plt.hist(recalls, bins = 100, range = [0,1])
plt.hist(loss, bins = 100)

##################### second training stage ###################################
for i, layer in enumerate(Model_base.layers):
   if ('mix' in layer.name):
       print(i, layer.name)
for layer in Final_model.layers[:275]:
   layer.trainable = False
for layer in Final_model.layers[275:]:
   layer.trainable = True

Final_model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), 
              loss='binary_crossentropy', metrics = ['acc'])
def train2_IncResNet_model(epochs = 21):
    global no_of_epochs
    Final_model.fit(x = train_images, y = train_labels, epochs = epochs)
    no_of_epochs = no_of_epochs + epochs
train2_IncResNet_model(epochs = 21)

result = Final_model.evaluate(test_images, test_labels)
for name, value in zip(Final_model.metrics_names, result):
    print(name, value)

### making predictions on the test data
predictions = Final_model.predict(test_images).squeeze(axis = 1)
binary_preds = predictions.round()
print(predictions[0:10], binary_preds[0:10])

# Plot a few images to see if the data is correct
images = test_images[9:18]
cls_true = test_labels[9:18].astype(int)
plot_images(images=images, cls_true=cls_true)
cls_pred = binary_preds[9:18]
plot_images(images=images, cls_true=cls_true, cls_pred = cls_pred)    

### checking test accuracy, example errors and confusion matrix
print_test_accuracy

### checking which layers are convolutional layers
for i, layer in enumerate(Model_base.layers):
   if ('conv' in layer.name):
       print(i, layer.name)

plot_weights(input_channel = 0, layer_index = 1)
plot_weights(input_channel = 1, layer_index = 1)


















#*****************************************************************************
################# HELPER FUNCTIONS ###########################################
#
#*****************************************************************************

### Helper function for confusion matrix #####################################
import itertools
classes = ['no sp', 'sp']

def plot_confusion_matrix(cm = cm, classes = classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum()
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")     
    plt.tight_layout(pad = 2)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


###### Helper function for plotting images ####################################
def plot_images(images, cls_true, cls_pred=None):
    assert len(images) == len(cls_true) == 9
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i], cmap='binary')
        if cls_pred is None:
            xlabel = "Label: {0}".format(cls_true[i])
        else:
            xlabel = "Label: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])
        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show() 
    
### Example errors
def plot_example_errors(cls_pred, correct):
    incorrect = (correct == False)
    images = test_images[incorrect]
    cls_pred = cls_pred[incorrect]
    cls_true = test_labels[incorrect]
    plot_images(images=images[0:9],
                cls_true=cls_true[0:9],
                cls_pred=cls_pred[0:9])

def print_test_accuracy(show_example_errors=True,
                        show_confusion_matrix=True, 
                        show_first_10_preds = True):
    num_test = len(test_images)
    #cls_pred = np.zeros(shape=num_test, dtype=np.int)
    cls_pred = Final_model.predict(test_images).squeeze(axis = 1).round()
    cls_true = test_labels
    correct = (cls_true == cls_pred)
    correct_sum = correct.sum()
    acc = float(correct_sum) / num_test
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))
    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)
    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        cm = confusion_matrix(test_labels, cls_pred.round())
        plot_confusion_matrix(cm = cm)
    # Show the first hundred predictions made:
    if show_first_10_preds:
        print("First 10 predictions:")
        print(cls_pred[0:10])


#### Helper function for plotting the output of a convolutional layer
#def plot_conv_layer(layer, image):
#    feed_dict = {x: [image]}
#    values = IncResNet_model.run(layer, feed_dict=feed_dict)
#    num_filters = values.shape[3]
#    num_grids = math.ceil(math.sqrt(num_filters))
#    fig, axes = plt.subplots(num_grids, num_grids)
#    for i, ax in enumerate(axes.flat):
#        if i<num_filters:
#            img = values[0, :, :, i]
#            ax.imshow(img, interpolation='nearest', cmap='binary')
#        ax.set_xticks([])
#        ax.set_yticks([])
#    plt.show()

### Helper function for conv weights
def plot_weights(input_channel=0, layer_index = 1):
    w = Final_model.layers[layer_index].get_weights()[0]
    w_min = np.min(w)
    w_max = np.max(w)
    num_filters = w.shape[3]
    num_grids = math.ceil(math.sqrt(num_filters))
    fig, axes = plt.subplots(num_grids, num_grids)
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            img = w[:, :, input_channel, i]
            ax.imshow(img, vmin=w_min, vmax=w_max,
                      interpolation='nearest', cmap='seismic')
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()
